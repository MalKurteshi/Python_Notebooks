# %% [markdown]
# # Exercise 3 (MapReduce in Practice)   &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;     [4 points]
# ---
#
# For this exercise, you are tasked with writing your own Hadoop MapReduce program in Python and to
# run it on the cluster on two provided datasets. The dataset for this exercise consists of freely accessible
# data from New York City, NY, USA. One is a [dataset containing parking and camera violations recorded](https://www.kaggle.com/new-york-city/ny-open-parking-and-camera-violations), and the other is a [dataset of taxicab permits (called “medallions”) with their respective license plates](https://www.kaggle.com/new-york-city/ny-medallion-vehicles-and-drivers).
# We provide a JupyterLab notebook file to write and execute MapReduce jobs directly on JupyterLab.
# You can find the datasets on the cluster under the following locations:
#
#
# * **local file system & Hadoop file system (HDFS)**
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;/home/adbs21/shared/medallion-vehicles.csv
# &nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;/home/adbs21/shared/parking-violations.csv
#
#
# ##
#
# - ### **a) Write a MapReduce job with “medallion-vehicles.csv” as input and following output:**
# For each company, show the number of license plates for which they received a medallion; make sure to have the following format in your final output:
#             name,count_license_plate
# The license plates are stored in the column “DMV License Plate Number”.
# Make sure that your program correctly deals with the header, and possible sparse values.

# %%
# %%file mymrjob1.py
# This will create a local file to run your MapReduce program  

from mrjob.job import MRJob
from mrjob.step import MRStep
from mrjob.util import log_to_stream, log_to_null
from mr3px.csvprotocol import CsvProtocol
import csv 
import logging

log = logging.getLogger(__name__)
# 
#  Below is the skeleton for a MapReduce program in mrjob.
#  Write your own solution here. Be sure that it actually runs successfully.
class MyMRJob1(MRJob):
    
    
    OUTPUT_PROTOCOL = CsvProtocol  # write output as CSV
    
    def set_up_logging(cls, quiet=False, verbose=False, stream=None):  
        log_to_stream(name='mrjob', debug=verbose, stream=stream)
        log_to_stream(name='__main__', debug=verbose, stream=stream)
        
#   Feel free to rename the functions
    def mapper_mrjob1(self, _, line):
        result = next(csv.reader([line]))
        name = result[1]
        p_no = result[4]
        
        if name == "Name" or p_no == "" or name == "": 
            return
        
        yield name, 1
               
# use of a combiner is optional. It may speed up your job. Be sure that using the combiner preserves the correctness. 
#     def combiner_mrjob1(self,key,valuelist):
        #TODO
        
    def reducer_mrjob1(self,name,value):

        yield None, (name, sum(value))

    def steps(self):
        first_step = MRStep(
            mapper=self.mapper_mrjob1, 
#             combiner=self.combiner_mrjob1, 
            reducer=self.reducer_mrjob1
        )
        # just generate more steps to run a multi-step MR job
        
        return [ first_step ]

if __name__ == '__main__':
    MyMRJob1.run()
# Out:
# Overwriting mymrjob1.py

# %% [markdown]
# Running a local MRjob

# %%
! python mymrjob1.py  /home/adbs21/shared/medallion-vehicles-short.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for inline runner
# Running step 1 of 1...
# Creating temp directory /tmp/mymrjob1.e11924480.20210425.075336.621293
# job output is in /tmp/mymrjob1.e11924480.20210425.075336.621293/output
# Streaming final output from /tmp/mymrjob1.e11924480.20210425.075336.621293/output...
# " CHAUDRY,TARIQ,J & CHOUDHRY,ABBAS,G",73
# "1212 TAXI LLC",192
# "16 WHITESTONE CAB LLC",209
# "168 CAB CORP",202
# "178 CAB CORP",204
# "18TH STREET HACKING CORP",231
# "1C39 LLC",23
# "1C46 LLC",37
# "1D89 ACQUISITION LLC",2
# "1F75 CORP.",14
# "1KHALSA LLC",56
# "1KHALSHA LLC",1
# "1T15 CORP",83
# "1T82 CORP.",16
# "2 BIRDS LLC",94
# "2 BROS TAXI GROUP LLC",46
# "2 BROTHERS CAB CORP",216
# "211 TAXI CORP.",99
# "2138 TRANS LLC",200
# "221 CAB LLC",103
# "222 EAST CORP",228
# "2510 PARSONS LLC",7
# "2C32 LLC",65
# "2D23 ACQUISITION LLC",5
# "2L73 & 2L74 ACQUISITION LLC",23
# "2T58 LLC",19
# "2T65 CORP.",14
# "2T79 LLC",34
# "3 BROTHERS TAXI LLC",127
# "333 CAB CORP.",165
# "3511 SYSTEMS INC",184
# "3511 SYSTEMS INC.",812
# "3535 TAXI INC",217
# "3B53 CORP.",73
# "3C94 CORP.",86
# "3D58 CORP.",87
# "409 TAXI CORP",220
# "44TH ROAD TRANS INC.",223
# "4B62 CORP.",19
# "4C25 LLC",25
# "4C67 CORP.",61
# "4F88 ACQUISITION LLC",1
# "4S CAB CORP.",94
# "4W46 CORP.",21
# "4W53 CORP.",15
# "5 D'S TAXI INC",206
# "5 TAARA VENTURES LLC",46
# "555 TAXI INC",221
# "5J165J17 LLC",112
# "63 BAL TRANSPORTATION LLC",73
# "66 CAB CORP.",206
# "6K106P87, LLC",1
# "6M566M57 LLC",123
# "6P106P87 LLC",64
# "6P106P87, LLC",51
# "7 HEAVEN TAXI INC",223
# "7 STAR TAXI LLC",54
# "7A1436, LLC",15
# "7C28 ACQUISITION LLC",1
# "7D81, LLC",47
# "7D86 LLC",11
# "7E74 ACQUISITION LLC",3
# "7F40 LLC",22
# "7F44 LLC",56
# "7T24 CORP.",75
# "888 EXPRESS TRANSPORTATION LLC",110
# "888 TAXI INC",233
# "962 TRANS INC.",109
# "99 CAB CORP.",227
# "99 NAMES INC.",43
# "9D93 LLC",21
# "9T57 CORP.",87
# "9T83 CORP.",12
# "A & A TAXI INC.",232
# "A & F TAXI INC",217
# "A & J CAB CORP",83
# "A & K TAXI CORP",209
# "A & R TAXI INC.",112
# "A & S TAXI LLC",100
# "A S JUDGE LLC",44
# "A T CAB CORP",195
# "A&B TAXI LLC",104
# "A. DUMAS TRANSIT INC",220
# "A. G. CAB CORP",221
# "A. W. TRANSIT INC.",230
# "A.A.T. TRANS INC",634
# "A.B.S. TRANSIT INC.",221
# "A.C.A.CAB CORP",192
# "A.M.E.X. LLC",89
# "A.P. CAB CORP.",23
# "A.P. TRANSIT INC",224
# "A.R.S.CAB CORP",213
# "A.V. TAXI INC.",74
# "AAA TAXI WAY HOLDING LLC",10
# "AAHIL LLC",38
# "AAKARSH TRANSPORTS INC.",132
# "AAMAAR & MAANNIKARAN TRANSIT CORP",234
# "AARON JACOB TRANSIT INC",222
# "AARON JACOB TRANSIT INC.",96
# "AARON TRANS INC",109
# "AARON TRANSIT INC",86
# "AARON,LOUIS,A",19
# "AAYALOLO HACKING CORP.",204
# "AAYAT CORP.",30
# "ABAEV, YAFA",103
# "ABAIDULLAH,MUHAMMAD",106
# "ABBA TAXI INC",309
# "ABBAS,AMJAD",87
# "ABBAS,FAIZ,CHOUDHARY",88
# "ABBAS,GHULAM",92
# "ABBAS,RAZA",114
# "ABBEL CAB CORP.",210
# "ABBU CAB LLC",123
# "ABC CAB LLC",96
# "ABC TAXI HOLDING LLC",6
# "ABC TAXI NYC, LLC",52
# "ABCON INC.",84
# "ABDELATTI,AHMED,R",63
# "ABDELLATIF,AHMED,M",106
# "ABDELWAHAB,ABDELWAHAB,A",72
# "ABDELWAHAB,SABAH",28
# "ABDOOL,FARIED",79
# "ABDOULAYE,BAGAYOGO",99
# "ABDU,MOHAMMED,N & HEDRU,HABTEAB,S",120
# "ABDUL HAMID LLC",42
# "ABDUL MALIK TAXI LLC",35
# "ABDULLAH, HAROON",111
# "ABDURAKHMANOV, DANIEL",76
# "ABEDIN,JOYNUL,M",117
# "ABEDNEGO,JOB",97
# "ABES SERVICE CORP.",225
# "ABHI & ARYAN TAXI LLC",1
# "ABI CAB CORP",236
# "ABID,ABDUL,H",117
# "ABIDA USA CORP.",47
# "ABIGONE LLC",90
# "ABM CAB CORP",195
# "ABMARI,LLC",108
# "ABOLA TAXI CORP",123
# "ABOUSALEM,HANY",90
# "ABOUZIED,YOUSRY,E",101
# "ABOZEID,TAREK,S & SOLIMAN,TAREK,F",92
# "ABRAEL SERVICE LLC",38
# "ABRAHAM, LEON",102
# "ABRAHAM, VARUGHESE K.",110
# "ABRAHAM,JOHN,K.",106
# "ABRALO SERVICE CORP.",204
# "ABRAMOV, MIKHAIL",86
# "ABRAMOV, RUBEN",98
# "ABRAMOV, VALERY",107
# "ABRAMOVITZ, JAKOB",63
# "ABRAMOWITZ, ALLEN",106
# "ABRAMSON, DAN",108
# "ABRASHKIN, VIACHESLAV",90
# "ABRO SERVICE CORP.",221
# "ABSCENTCAB CORP.",104
# "ABSENTCAB CORP.",102
# "ABUBAKAR,MOHAMMED",49
# "ABUGHAZALEH,AMR",17
# "AC CAB LLC",98
# "AC TAXI CORP.",9
# "ACCA TRANS CORP.",212
# "ACCAD CAB CORP",220
# "ACCEPTABLE TAXI LLC",197
# "ACCRA LLC",91
# "ACGSA TRANSIT INC",190
# "ACHILLE,SERGE",69
# "ACJ HACKING CORP",223
# "ACKA TAXI CO.,INC.",212
# "ACLUCHE, PRESSOIR J.",68
# "ACROPOLIS TAXI INC.",179
# "ACTION TEAM INC",90
# "ACTIVE CAB LLC",63
# "ACTIVE TAXI CORP",312
# "ADA TAXI CORP",187
# "ADAM SETH TAXI INC",235
# "ADAM28 TAXI LLC",7
# "ADAMCZYK,ZBIGNIEW",108
# "ADAMIZZA,LLC",66
# "ADAMS, MUTAWAKILU, S.",118
# "ADAMS,ABDUL,R",99
# "ADANO SERVICE CORP",204
# "ADBAUM CAB CORP",229
# "ADDAI,GORDON",90
# "ADDAI-MENSAH,MAXWELL",86
# "ADDANE,KWASI",81
# "ADEGBO,NEWTON,D",99
# "ADELA CAB CORP",213
# "ADELPHI TAXI CORP",216
# "ADI HACKING CORP",217
# "ADIBA & RATUL INC.",64
# "ADIGUZEL,AYDIN",111
# "ADINAMIA MOU INC",339
# "ADJEI, KWABENA & KODUA, NANCY",82
# "ADJEPONG,AUGUSTINES,A",81
# "ADJOKATCHER,MICHAEL, K.",89
# "ADMIRAL OPERATING CORP",220
# "ADMIRE MY TAXI LLC",219
# "ADOLPHE,JEAN,YONEL",102
# "ADOM, KWABENA",86
# "ADOM,NANA,K",51
# "ADOMAKO,KWABENA SR.",71
# "ADR TAXI CORP",219
# "ADRIEN, MAX PIERRE",107
# "ADULT SERVICE CORP",211
# "ADV4 LLC",46
# "AEA TAXI CORP",112
# "AEC CAB CORP.",112
# "AELS TAXI LLC",19
# "AEM TRANSPORTATION CORP",217
# "AERO TAXI CORP",337
# "AETNA TAXI CORP",333
# "AFERITASH HACKING CORP",195
# "AFORIA CAB CORP",213
# "AFRIAT,NATAN & ORLY",117
# "AFTAB CAB CORP.",105
# "AFTABUN NESSA LLC",109
# "AFZAL TRANSPORTATION CO LLC",96
# "AFZAL,MOHAMMAD",98
# "AGAM TAXI INC.",80
# "AGAPE-MOU CAB CORP",206
# "AGATES TRANSIT INC.",225
# "AGBAI,EMMANUEL,C",99
# "AGEN TAXI CORP",205
# "AGI SERVICE CORP.",189
# "AGIOKLIMA LLC",192
# "AGION OROS TAXI INC",218
# "AGIOS ANTONIOS LLC",9
# "AGIOS GIORGIOS LLC",17
# "AGIOS SAVVAS TAXI LLC",206
# "AGOON LLC",116
# "AGORA TAXI CORP",138
# "AGROGOTI LLC",112
# "AGUAGALLO,JOSE",95
# "AGUR CORP",206
# "AGYEMANG, ALBERT",99
# "AHAD TAXI LLC",51
# "AHAMED,MOHAMMAD,K",110
# "AHARONY TAXI CORP",209
# "AHIA TAXI INC.",88
# "AHIZAF TAXI LLC",109
# "AHLUWALIA, KULVINDER",93
# "AHMAD, AZIZ",102
# "AHMAD, MOHAMMAD S.",67
# "AHMAD,AFTAB",11
# "AHMAD,CHOUDARY,A",99
# "AHMAD,FAIZ",122
# "AHMAD,MUSHTAQ",106
# "AHMAD,MUZAFFAR",97
# "AHMAD,NIAZ",117
# "AHMAD,WAHEED",109
# "AHMED & KHAN LLC",47
# "AHMED TAXI LLC",113
# "AHMED, ALTAF H.",108
# "AHMED, BASHIR",98
# "AHMED, IFTEKHAR",85
# "AHMED, MUHAMMAD",1
# "AHMED, SYED R.",38
# "AHMED,AHAD",105
# "AHMED,ALAUDDIN & UDDIN,MOHAMMED",31
# "AHMED,ALAUDDIN & UDDIN,MOHAMMED,J",64
# "AHMED,ANWAR I.",102
# "AHMED,FARID",87
# "AHMED,FARUK & RAHMAN,MIZANUR",112
# "AHMED,FARUQUE",97
# "AHMED,FORAZ",82
# "AHMED,HAFEEZ",103
# "AHMED,IFTIKHAR &KHAN,AKHTAR",96
# "AHMED,JASIM,UDDIN",5
# "AHMED,JUYEL",102
# "AHMED,KAMAL",101
# "AHMED,KAWSAR & ISLAM, MOHAMMAD",115
# "AHMED,MAMDOH,S",86
# "AHMED,MOHAMMED",112
# "AHMED,MUKHTAR",90
# "AHMED,RASHID & MAHMOOD,TAHIR",103
# "AHMED,RIAZ & RIAZ,AJMAL",99
# "AHMED,ROMANA",113
# "AHMED,SARFRAZ & AHMED,WAQAR",28
# "AHMED,SHABBIR",139
# "AHMED,SHAFAYET",115
# "AHMED,SHAFIQUE",41
# "AHMED,SHAHZAD",93
# "AHMED,SHAKE,R",90
# "AHMED,TALUKDER,S",117
# "AHOEY,HAMID,ASGHARY",76
# "AIDA CAB CORP",210
# "AIM HIGH CAB CORP",230
# "AIME, MARC",91
# "AIME,FRANTZ",85
# "AINOS TAXI INC",183
# "AIR CAB LLC",11
# "AJAY & SANDHU,LLC",39
# "AJB TRANSIT INC",203
# "AJIT CAB CORP",219
# "AJL CAB CORP.",192
# "AJVINDER SINGH & AMARJIT S. RANGI",43
# "AKABALU,LAWRENCE,O",103
# "AKAL TAXI NYC LLC",99
# "AKBAR, ALI",84
# "AKBAR, MOHAMMAD",124
# "AKBAR,MOHAMMAD",105
# "AKBAR,ZAHEER",102
# "AKBARYAR,ABDUL,M",97
# "AKHTAR JAVED & ASGHAR ALI",128
# "AKHTAR, JAVED",108
# "AKHTAR,JAVED",82
# "AKHTAR,MASOOD",228
# "AKHTAR,MUHAMMAD,S",16
# "AKHTAR,NAVEED",112
# "AKHTAR,PERVAIZ & CHAUDHRY,NISAR,K",24
# "AKK, INC.",196
# "AKLAI, SAM",94
# "AKLEY, SIHAM",106
# "AKOLA TAXI CORP",206
# "AKRAM,MOHAMMAD",106
# "AKRON TAXI CORP",217
# "AKSAVAS, ERCAN",103
# "AKTAS, GAZI",89
# "AKTASH,DERVISH",70
# "AKTURK, HIKMET",97
# "AL-ANN CAB CORP",194
# "AL-EL CAB CORP",207
# "AL-NA CAB CORP",58
# "ALAA-ERA INC",68
# "ALAM, AFSARUL",118
# "ALAM, MOHAMMED, S.",77
# "ALAM,MASUD",104
# "ALAM,MD,SAZZADUL",96
# "ALAM,MOHAMAD,M",34
# "ALAM,MOHAMMAD,K",113
# "ALAM,MOHAMMAD,SHAH",114
# "ALAM,MOHAMMED,F",103
# "ALAM,MOHAMMED,S",88
# "ALAM,MOHAMMED,T",100
# "ALAM,NOOR",117
# "ALAR HACKING CORP",201
# "ALARCON,JAIME,E",98
# "ALASKA TAXI INC",199
# "ALAUDDIN,DEWAN",84
# "ALAYEV,YADIDIYA",104
# "ALBEE TAXI CORP",326
# "ALBNAT INC.",103
# "ALBRO HACKING CORP.",200
# "ALBU,MICHAEL",114
# "ALBUJA, HERALDOA",95
# "ALCIDE,EPHRAIM",72
# "ALCIME,ALCIMA,J",77
# "ALCINAY,JOSEPH,J",81
# "ALCO TAXI CORP",305
# "ALCOB CAB CORP",203
# "ALDAMOOR TAXI CORP",99
# "ALEGAR CAB CORP",216
# "ALEKA TAXI INC.",226
# "ALEX & CHRIS INC",224
# "ALEX & EUGENE CAB CORP",207
# "ALEX CAB CORP",210
# "ALEX, CHACKO C.",101
# "ALEXANDER TAXI CORP",184
# "ALEXANDRA BEATRICE ARITON LLC",63
# "ALEXANDRA TAXI INC",391
# "ALEXANDRE, ANDRE",86
# "ALEXANDRE, JEAN",102
# "ALEXANDRE, PIERRE J.",98
# "ALEXANDRE,FRANTZ",110
# "ALEXANDRE,LOUBERT",59
# "ALEXANDRE,MARIE,Y",96
# "ALEXIADIS,MATHEOS",18
# "ALEXIS 3 PARTNERS LLC",1
# "ALEXIS' TAXI LLC",57
# "ALEXIS, MARC",103
# "ALEYA, LLC",104
# "ALGI TAXI CORP.",220
# "ALHAMDULILAH CORP.",33
# "ALI 777 LLC",12
# "ALI HASAN CORP.",126
# "ALI TAXI NYC LLC",48
# "ALI, KORBAN",98
# "ALI, SAFDAR",42
# "ALI,ADNAN",68
# "ALI,ANDREW",116
# "ALI,ARIF",49
# "ALI,FARAH",101
# "ALI,FARMAN",110
# "ALI,MD,FORHAD",109
# "ALI,MOHAMMAD",92
# "ALI,MOHAMMAD,A",112
# "ALI,MOHAMMAD,IDRIS",106
# "ALI,MOHAMMAD,IJAZ",89
# "ALI,MOHAMMED,PORASH",99
# "ALI,NURUZZAMAN,R",112
# "ALI,SHEHZAD & ASHFAQ,MOHAMMAD",70
# "ALI,TAHIRU,M",78
# "ALICE TAXI INC",106
# "ALIDA CAB CORP",111
# "ALIG TRANSIT INC",219
# "ALIKA AWAN TRANS CORP.",46
# "ALINA TRANSIT INC.",226
# "ALIP CAB CORP",171
# "ALISKY TOYOTA LLC",87
# "ALITHIA TRANSPORT LLC",102
# "ALIYU,MOUHAMADOU",116
# "ALL BORO LLC",87
# "ALL NIGHT TAXI LLC",326
# "ALL SOULS CAB CORP.",110
# "ALL WOOD, LLC",96
# "ALLAN TRANSIT INC.",214
# "ALLEGRO TRANSIT INC",186
# "ALLHASSAN OSMANU & ANDREW DARKO",122
# "ALLIE CAT CAB CORP.",32
# "ALLIED CAB LLC",57
# "ALLIS CAB CORP",217
# "ALLMAY CAB CORP",133
# "ALLOSHA TAXI INC",124
# "ALLOVER TAXI INC",240
# "ALLRICH TRANS LLC",110
# "ALLRUD HACKING CORP",210
# "ALLTAXIONE CAB CORP.",150
# "ALLTAXITWO CAB CORP.",187
# "ALMA TAXI CORP",308
# "ALMAMS INC.",3
# "ALMANAC HACKING CORP",103
# "ALMIC TRANSIT INC",200
# "ALMODOVAR, ISMAEL",92
# "ALMONORD,EVENS",114
# "ALMONTE CAB CORP.",23
# "ALO  TAXI CAB CORP.",113
# "ALOHA CAB CORP",207
# "ALOUIDOR,DANIE",103
# "ALPHA TRANSIT LLC",68
# "ALPHONSE,LOUIS A.",82
# "ALPIE HACKING CORP",204
# "ALRO CAB CORP",240
# "ALTA TAXI SERVICE INC",208
# "ALTAGRACE TRANSPORTATION SERVICE INC",171
# "ALTAYGIL, ILKER",93
# "ALTENOR, ALFREDO & GUERRY",102
# "ALTES RAYMONVIL",87
# "ALTIDOR,JEAN,CLAUDE",72
# "ALTMAN, ROMAN",100
# "ALVAREZ, HEBER & SONIA",100
# "ALVAREZ, MARIA",88
# "ALVAREZ,ARMANDO",115
# "ALVAREZ,LEONIDAS",113
# "ALVEE TAXI CORP.",76
# "ALVERNA,JEAN,L",102
# "ALVES, PAULO",88
# "ALY,HENS",121
# "ALYAS,MOHAMMAD",107
# "AM DUKE CORP",68
# "AMA TAXI INC",207
# "AMAL CAB CORP.",117
# "AMALIA-MOLLY LLC",91
# "AMALO SERVICE CORP.",217
# "AMAN & ROHAN CAB LLC",39
# "AMAN AMAR CAB CORP",216
# "AMANDA TRANSIT INC.",225
# "AMANDA'S CAB CORP.",188
# "AMANKWAA,KWASI",27
# "AMANKWAH,ANDY",115
# "AMAR DHAH LLC",18
# "AMAR KAUR LLC",17
# "AMARJAG CAB CORP",176
# "AMARJEET SINGH DHALIWAL & HARSIMRANJIT DHALIWAL",105
# "AMARJIT TAXI CORP.",83
# "AMARJIT,AMAR",68
# "AMAZAN INC.",102
# "AMBERY, GEORGE E.",32
# "AMBRO, IONEL",104
# "AMBRO,DANIEL",28
# "AMC TAXI INC",222
# "AMENA CAB CORP.",100
# "AMERICAN OPERATING CORP",228
# "AMERICAN TRANSYLVANIAN CORPORATION",46
# "AMERIMIMI CAB CORP.",155
# "AMERPAK TRANS CORP",214
# "AMEZIN TRANS CORP.",8
# "AMEZQUITA, FRANCISCO",85
# "AMG TAXI INC.",87
# "AMIE CAB CORP",217
# "AMIN & ANWAR BROS LLC",99
# "AMIN & TARAQ INC.",110
# "AMIN, MD, SAIFUL",22
# "AMIN,MD,N.",24
# "AMIN,RAHUL",28
# "AMINI,SHIR",85
# "AMINOV, NAUM",93
# "AMINOV, VALERI",133
# "AMIR ALI & IRFAN ALI",71
# "AMIR MASSOUD INC.",77
# "AMIRA TAXI INC.",112
# "AMITY TRANSPORTATION INC.",228
# "AMME TAXI INC",211
# "AMNA TAXI CABS CORP",25
# "AMNM LLC",99
# "AMOAFO,FREDERICK",101
# "AMOFA,PAUL KWABENA",101
# "AMOLAK TAXI LLC",29
# "AMOUR TAXI INC.",144
# "AMPADU,KWASI",114
# "AMPADU,SAMUEL",72
# "AMPH TRANSPORTATION LLC",93
# "AMPORFRO, ROBERT",113
# "AMRON CAB CORP",116
# "AMSTERDAM CAB CORP.",202
# "AMY & MARK CAB CORP",252
# "ANA LEX TAXI INC",118
# "ANANYA TAXI CORP",106
# "ANASTASIA TRANS INC",173
# "ANASTASIADIS,DULARIE& IOANNIS",87
# "ANASTASIOS, SIALAKAS",103
# "ANAYA, JAIME",88
# "ANBA TAXI INC",224
# "ANCHOR CAB CORP",311
# "ANCHORAGE NEW YORK LLC",13
# "ANDAZ CAB LLC",85
# "ANDIAMO TAXI LLC",110
# "ANDRE,DECERECE",96
# "ANDRE,LORIGENE",106
# "ANDRE,STELLUS,V",105
# "ANDREA TAXI LLC",99
# "ANDREW'S TAXI EXPRESS CORP",224
# "ANDREWS,ERIAN",64
# "ANDROID TAXI LLC",99
# "ANDY TRANS CORP",233
# "ANEDU,CHARLES,U",110
# "ANEJA,INDERJIT,S & ANEJA,MANPRIT,S",97
# "ANEMONE TAXI INC",234
# "ANEMOS TAXI LLC",9
# "ANEPANALYPTOS LLC",218
# "ANESTHITOS INC.",202
# "ANGEL ADEPA LLC",126
# "ANGEL, DIVINA",70
# "ANGELICA CAB CORP.",7
# "ANGELINO CAB CORP",110
# "ANGELITA TRANSIT INC.",156
# "ANGELOPOULOS, PETER",87
# "ANGLADE,EVENS",110
# "ANGLADE,JEAN-CLAUDE",121
# "ANGUS CAB CORP",211
# "ANIL,MUHAMMAD,A",109
# "ANIS TAXI INC",195
# "ANISSE,BOULOS,Y",102
# "ANITA-NIDHI CAB CORP",233
# "ANJAC CORP",194
# "ANJUM,RIAZ",89
# "ANJUM,ZAHID",62
# "ANKA ENTERPRISES, LLC",86
# "ANKIT INC.",107
# "ANKUMAR, VIJAI",3
# "ANLZ CAB LLC",27
# "ANN TAXI INC",265
# "ANNA & DIANA CAB CORP",223
# "ANNA TAXI INC",92
# "ANNIVERSARY TAXI CORP",209
# "ANORGA,WILFREDO",74
# "ANOSTERE JEAN AND MACELIN ALEXIS",42
# "ANOTHER TAXI LLC",127
# "ANSAH,YAW,O",52
# "ANSAR,MOHAMMAD",106
# "ANSARI,MUHAMMAD",102
# "ANSO TAXI CORP",73
# "ANT CAB CORP.",162
# "ANT TAXI INC",222
# "ANTARES SERVICE LLC",97
# "ANTBILLY LLC",109
# "ANTHONY TAXI CORP",220
# "ANTIBES TAXI INC",75
# "ANTIC TRANS INC",201
# "ANTILUS, ELOGE A.",108
# "ANTOINE, RAPHAEL",80
# "ANTOINE,FRIBERT & PARIS,DALTON",114
# "ANTOINE,PIERRE,Q",118
# "ANTON, AUREL PETRE",106
# "ANTONIS LLC",100
# "ANUPAMA CAB CORP.",92
# "ANVI NYC CORP",113
# "ANWAR,ARIF",107
# "ANWAR,MOHAMMAD & MAHMOOD,MUHAMMAD",106
# "ANZ INC",104
# "AP TAXI MANAGEMENT, LLC",28
# "APACHE ARROW CAB, LLC",59
# "APANDREAS TAXI INC.",48
# "APART CAB CORP",206
# "APEX MANAGEMENT NYC INC.",12
# "APG TAXI LLC",95
# "APHRODITE HACKING INC",214
# "APOH TAXI CORP",50
# "APOH, JACOB",28
# "APOLLO CAB CORP",229
# "APON MEDALLION INC.",49
# "APONTE, RAFAEL",78
# "APOSTOLESCU, MARIUS",106
# "APPANOOSE TAXI CORP",207
# "APPEAL CAB CORP",212
# "APPIAH,ANTHONY,P",101
# "APPIAH,FAROUK",13
# "APPLE CAB CORP",204
# "APPLYRS, MARIE",78
# "APPOINT CAB CORP",79
# "APPOLON, YVON",21
# "APRICOT CAB LLC",57
# "APRIL TAXI INC",222
# "APRON CAB CORP",211
# "APT TAXI CORP",326
# "AQUARIUS TAXI CORP",106
# "AQUINO, ACHILLE",86
# "AR RAHMAN EXPRESS CAB CORP.",97
# "AR-RAHMAN INC.",117
# "ARABY SERVICE CORP",221
# "ARAGVI TAXI INC.",201
# "ARAT TAXI INC",100
# "ARBAT TAXI INC.",203
# "ARBEN CAB CORP",214
# "ARBOLEDA, ANTONIO",78
# "ARCAN CAB CORP",244
# "ARCHIBALD, GEORGE A.",120
# "ARCHILLE, ARNOLD",97
# "ARCHILLE, ROLAND",110
# "ARCHILLE,CONSTANT",110
# "ARE CAB CORP",213
# "AREA CAB CORP",201
# "ARETI TRANS INC",222
# "AREVALO,FABIO",71
# "ARGENTINA OPEN POLO CORP.",206
# "ARGOLIK TRANSIT INC",211
# "ARGY & GEORGE TRANS INC",90
# "ARGY & NICK TAXI INC",101
# "ARGYLE TRANSPORTATION INC.",183
# "ARHIDIA LLC",219
# "ARHONTAS INC.",35
# "ARIA & ADIBA LLC",80
# "ARIANNAADRIAN, LLC",39
# "ARIAS, GERARDO",97
# "ARIDAN SERVICE CORP",159
# "ARIE H, LLC",78
# "ARIEL CAB CORP",222
# "ARIES TAXI CORP",140
# "ARIETTE CAB CORP",151
# "ARIF,MD,ALI,H",106
# "ARIF,MOHAMMAD",188
# "ARIFUR TAXI LLC",101
# "ARION TRANSIT INC",204
# "ARIS CAB CORP",159
# "ARIS HACKING INC.",210
# "ARIS,RAYMOND",123
# "ARISME, MARIE, Y.",99
# "ARISTIDE, HILAIRE E.",100
# "ARISTIDE, JOSEPH E.",108
# "ARISTILDE, ANTOINE",15
# "ARISTILDE,EXTRAIVOOF",33
# "ARISTON CAB CORP",236
# "ARISTOTELIS O STAGERITIS TAXI INC",220
# "ARITON DORU-PAUL LLC",52
# "ARJUN & SIMRAN, LLC",22
# "ARJUN CAB LLC",65
# "ARK TAXI INC.",306
# "ARKA MEMORY CAB CORP",212
# "ARKADY YELLOW CAB CORP",203
# "ARLA TAXI INC.",199
# "ARM TRANS CORP",180
# "ARMAGH CAB CORP",215
# "ARMAN AND MEHTAB PADDA TAXI CORP.",109
# "ARMAND,FRED",107
# "ARMIC SERVICE CORP",323
# "ARMONK LEASING CORP",198
# "ARNAL CAB CORP",54
# "ARNOB SARNOB SUVO TAXI LLC",54
# "ARNOLD HACKING R CORP.",148
# "ARNOUX,FRITZ",113
# "ARONOV HACKING CORP",116
# "ARONOV, MIKHAIL",110
# "ARONOV, ROSHEL",63
# "ARONOV, SHALOM D",81
# "ARONOVA, NATALYA",6
# "AROUSE TAXI INC",212
# "ARPA TRANS INC",193
# "ARR TRANSPORT INC.",113
# "ARROW CAB LLC",61
# "ARROYAVE, HECTOR",127
# "ARS & SAV LLC",101
# "ARSH TRANSPORTS INC",125
# "ARSHAD,OMEIR",106
# "ARSHID,MOHAMMAD",111
# "ART CAB CORP",218
# "ARTEMIS TRANSPORT INC",207
# "ARTHUR TAXI SERVICE INC",291
# "ARTHUR'S GOLDEN KEY INC.",221
# "ARTHUR, MATILDA",90
# "ARTHUR,WISLER",72
# "ARTICHOKE CAB CORP",195
# "ARTIS,VICAIRE",74
# "ARTMAR TAXI INC",343
# "ARTNAT TRANS CORP",325
# "ARTUNIAN, GEORGE",110
# "ARTY,JACQUES",81
# "ARULIN, PAVEL A.",112
# "ARVE CAB CORP.",219
# "ARVINDER RAVNEET LLC",118
# "ARWAND,NASRIN,N",97
# "ARYAN SHANKY TAXI LLC",57
# "ARZAN TRANS LLC",97
# "ARZAYUS TRANSIT INC.",233
# "AS CAB CORP",30
# "AS CAB CORP.",33
# "AS7 LLC",42
# "ASAD AND AYESHA CAB LLC",1
# "ASAD TAXI NYC LLC",45
# "ASAF EXPRESS CORP",235
# "ASAMOAH,PAUL",83
# "ASANTE, BENJAMIN",104
# "ASAVA TRANS CORP.",198
# "ASBEK TRANSPORTATION LLC",50
# "ASGHAR,AFSHIAN",113
# "ASGHAR,CHAUDHRY,M",75
# "ASGHAR,FAISAL",123
# "ASH TRANS CORP",208
# "ASHAMAL CAB CORP.",172
# "ASHAR ALO LLC",112
# "ASHAVINDER LLC",114
# "ASHKA CAB CORP",192
# "ASHKINADZE, PINIA",106
# "ASHLEY CAB CORP.",238
# "ASHMAWY,ASSAD,K",72
# "ASHMED TRANSIT INC.",217
# "ASHOKA CAB LLC",329
# "ASHRAF & SONS LLC",107
# "ASHRAF D&S LLC",4
# "ASHRAF, MOHAMMAD",112
# "ASHRAF,MOHAMMAD",129
# "ASHRAF,MOHAMMAD,P",84
# "ASHRAF,NADEEM",97
# "ASHRAF,NAEEM",95
# "ASHU & PRABH, LLC",111
# "ASHU BABA TAXI LLC",55
# "ASIAMAH,ERIC & ASIAMAH,MICHAEL",96
# "ASIF,MOHAMMAD",74
# "ASLAM TASLIMA LLC",54
# "ASLAM, MOHAMMAD & KHARAL MOHAMMAD",3
# "ASLANIDIS,HARILAOS,S",118
# "ASMAH,JOHN,S",104
# "ASPEN CAB CORP",203
# "ASPEN TAXI LLC",33
# "ASSAMOAH,KOFI",130
# "ASTERIK CAB CO. INC.",225
# "ASTORIA YELLOW CAB CORP.",111
# "ASTRA TAXI INC",228
# "ASTREP SERVICE CORP",112
# "ASYA TAXI INC",108
# "ASZANGI LLC",96
# "ATALLAH,MEDHAT,F",102
# "ATANELOV,ILYA",86
# "ATEN TAXI INC.",207
# "ATHANASIOS TAXI LLC",36
# "ATHENA MOTOR LTD",242
# "ATHENS,GEORGE & ATHANASIADIS,EVANGELOS",111
# "ATIQ,HAFIZ,M",76
# "ATIS & ASSOCIATES CORP.",65
# "ATLANTIS TAXI INC",216
# "ATLAS AGAMI CAB CORP",239
# "ATLAS, YEFIM",98
# "ATM TRANS CORP",208
# "ATOLL TAXI INC",180
# "ATOM TRANSIT LLC",211
# "ATWAL,BHUPINDER,S",75
# "AUBOURG,ALPHONSE&LAROQUE,RAYMOND",110
# "AUDELIEN, MARIE ROSENA",106
# "AUDREY SERVICE CORP",219
# "AUGUSTE, ANTONIO",116
# "AUGUSTE, FRITZNEL",64
# "AUGUSTE, JEAN G.",115
# "AUGUSTE,JEAN,B,E",65
# "AUGUSTIN, FRITZ",107
# "AUGUSTIN, JEAN BAPTISTE",74
# "AUGUSTIN, JEAN P.",99
# "AUGUSTIN, JOSEPH O.",106
# "AUGUSTIN, SMITH",80
# "AUGUSTIN,ROBERT & JOSEPH,JUNEL",104
# "AUGUSTIN,YVON",101
# "AUJALA,PARAMJIT & AUJLA,HARDEEP S",92
# "AUJLA CAB CORP",215
# "AUJLA,MANJINDER,SINGH",110
# "AULAKH,MANOHAR & BAINS,AMANDEEP",97
# "AULOV, ITSHAK",108
# "AULOV, JOSIF",66
# "AUNG, THEIN",98
# "AUNS CAB LLC",18
# "AURELUS, LISSADE",103
# "AUSTIN HACKING CORP",215
# "AUTA TAXI LLC",68
# "AUTHENTIC RIDE LLC",8
# "AUTUMN CAB CORP",183
# "AUYEUNG, GABLE C.",93
# "AVA CAB CORP",208
# "AVALANCHE HACKING CORP",222
# "AVANT CAB CORP",186
# "AVAR TAXI CORP",204
# "AVEDON,MARVIN",37
# "AVEROPOULOS, ATHANASIOS",100
# "AVEZBAKIYEV,YAIR",29
# "AVI TAXI CORP",199
# "AVIGNON TAXI LLC",81
# "AVILES, TORIBIO",115
# "AVILIE SERVICE INC",209
# "AVIS CAB CO INC",223
# "AVISAR HACKING CORP",197
# "AVIT TRANSIT INC.",98
# "AVIVS CAB CORP",323
# "AVON EXPRESS CAB CORP",197
# "AVRAMIDIS, ELEFTHERIOS",30
# "AVTER,VLADIMIR",129
# "AW CAB CORP.",231
# "AWAD,RUSSELL",97
# "AWAL,ABDUL & HOSSAIN,MOHAMMAD,M",81
# "AWAN,AHMAD,B",103
# "AWAN,FAIZ & AWAN,KHURSHEED",117
# "AWAN,MUHAMMAD,A",106
# "AWAN,ZAFAR,IQBAL",109
# "AWAY CAB CORP.",56
# "AWWAD,ESAMELDIN,M & ELMASKENY,AHMED,E.",100
# "AXIOS TAXI INC.",109
# "AYA CAB CORP",210
# "AYAM TAXI INC.",222
# "AYBINDER, MAX",97
# "AYDA, LLC",47
# "AYDEMIR,MEHMET,S",9
# "AYE AYE TRANS CORP",181
# "AYER CAB CORP",210
# "AYESHA TAXI INC.",98
# "AYSHA TAXI CORP",54
# "AZ TAXI CORP.",24
# "AZA TAXI LTD",218
# "AZAD EMRAN LLC",24
# "AZAD TAXI CORP.",88
# "AZEEZ, AFZAL",116
# "AZHAR,MOHAMMAD",118
# "AZIM,ANOWARUL",109
# "AZIN, KAZEM MOHAMMAD",109
# "AZIZ ABDEL",90
# "AZIZ, ABDUL",85
# "AZMON, JOSEPH",84
# "AZOR, PIERRE M.",98
# "AZOR,PIERRE,G",110
# "AZOY TRANSIT LLC",249
# "AZUAY LLC",93
# "B & A ASSOCIATES",14
# "B & B TAXI INC",183
# "B & D RIDE HACKING CORP",319
# "B & J LLC",113
# "B & L CAB CORP",113
# "B & M HACKING CORP",200
# "B L TRANSIT INC",195
# "B R S CAB CORP",192
# "B U TAXI LLC",310
# "B&A TAXI LLC",136
# "B&C CAB CORP",208
# "B&F TAXI INC",227
# "B&K TAXI CORP.",33
# "B&R EXPRESS CAB CORP",200
# "B.E.J.A.TAXI CORP",214
# "B.G. CAB CORP",219
# "B.K.V.TAXI TRANS. INC.",193
# "B2 NYC LLC",105
# "BAAFI, ATTAH",122
# "BABA FAREED CAB CORP.",50
# "BABA MELA SINGH TAXI CAB LLC",99
# "BABA NAGA LLC",109
# "BABA NANAK CAB CORP.",110
# "BABA OAK TREE LLC",212
# "BABABEKOV, NISON",111
# "BABADZHANOV, NISON",107
# "BABADZHANOV,ALBERT",122
# "BABAEV, MAXIM",105
# "BABAGANOV, JACK",94
# "BABAR,MUHAMMAD",103
# "BABAYEV,DZHURA",110
# "BABAYEV,SERGEY",89
# "BABAZORAWAR & FATEH SINGH LLC",39
# "BABBA TRANSIT LLC",236
# "BABICZ, VICTOR O.",107
# "BABY EXPRESS CAB CORP",229
# "BABY TRANS CORP",222
# "BABYLON TAXI LLC",37
# "BACARES, AXEL",96
# "BACHELOR SERV. CORP.",186
# "BACHELOR SERVICE CORP",47
# "BACK CAB CORP",181
# "BACK,ALAN",93
# "BACKYARD PARTIES LLC",22
# "BADA BING TAXI LLC",104
# "BADALUTA, VASILE",68
# "BADDAR,SAMY",95
# "BADEA, SARMIZA R.",107
# "BADEAU SERVICE CORP",213
# "BADGER TAXI LLC",82
# "BADHON HALDER LLC",36
# "BADRUL AND SULTANA ENTERPRISE INC",30
# "BAE,JOHNNY",91
# "BAFFOUR-GYAU,AMOS B.",77
# "BAGATELLE TAXI LLC",23
# "BAGHAIE, ABBAS",121
# "BAGHIANA,MALKIT",103
# "BAGINYA CAB CORP",178
# "BAGLIO, PETER S.",62
# "BAHAD TRANS INC.",105
# "BAHALOUL, ALBERT",33
# "BAHAMA TAXI INC",200
# "BAIC CAB CORP",299
# "BAIDWAN BROTHERS LLC",112
# "BAIDWAN, SURINDER S.",23
# "BAIG,ABDUL,A.",9
# "BAIG,ARSHAD & KHAN,RAI,WAHEED",109
# "BAIG,MIRZA,G.",45
# "BAIG,MIRZA,SHERAHMED",21
# "BAIG,MOHAMMAD & SIDDIQUE,MIRZA",109
# "BAINS,BHAJAN,S",122
# "BAINS,DALWINDER",107
# "BAIRES TRANSIT INC.",199
# "BAJWA,GURNAM",82
# "BAKATSIAS, CHRISTOS",110
# "BAKSH, FAREED",88
# "BAL CAB CORP",197
# "BAL TAXI LLC",62
# "BAL,AMARJIT,S",113
# "BALAN 63 LLC",54
# "BALDASSARRE,HECTOR,L",118
# "BALDEEP MANN TAXI CORP.",143
# "BALE SERVICE CORP",206
# "BALIN SERVICE CORP",180
# "BALISAGE, WISLER",66
# "BALKAR & SONS LLC",93
# "BALL CAB CORP",214
# "BALLINA CAB CORP",305
# "BALM CAB CORP",211
# "BALRAJ LLC",100
# "BALSAM CAB CORP",423
# "BALTER, MIRON",83
# "BALWANT SINGH & VIRKRAMJIT SINGH",102
# "BAMA CAB CORP",201
# "BAMBI CAB CORP",206
# "BANANA CAB CORP",144
# "BANANA EXPRESS CAB CORP",136
# "BANANI EXPRESS, INC.",5
# "BANATTE,WILSON",87
# "BANDHU,PUSHAP",72
# "BANFUL,ISAAC,K",105
# "BANGAY,SANTOKH",119
# "BANGIEV, YURY",88
# "BANGLA CAB CORP",97
# "BANGLA LION INC.",87
# "BANGLE CAB LLC",9
# "BANGY TAXICAB CORP.",68
# "BANIPAL,BHUR,SINGH",102
# "BANISOR,TRAIAN",90
# "BANKER, HOWARD S.",80
# "BANKER, JEAN, A.",18
# "BANSAH,KOJO",118
# "BANSAL,KULWINDER,S",110
# "BANTA TAXI 19 LLC",3
# "BANTA TAXI 20 LLC",3
# "BANTA TAXI 27 LLC",1
# "BANTA TAXI 29 LLC",1
# "BANTA TAXI 31 LLC",1
# "BAPTISTE,EROLL",64
# "BAPTISTE,JEAN,S",88
# "BAPTISTE,LERONES",86
# "BAQIR,NIAZ",96
# "BAR-JEN TAXI INC",179
# "BAR-TOV HACKING CORP",222
# "BARAHONA,ANGEL",38
# "BARAN, STANISLAW",90
# "BARBANEL,JACK",131
# "BARBIER, ANTONINE",50
# "BARBIER, YVON",75
# "BARCELONA TAXI INC",72
# "BARCLAY, CHARLES B.",107
# "BARD TAXI INC",180
# "BARGAIN TRANSIT LLC",180
# "BARGE TAXI INC",186
# "BARHA TAXI INC",108
# "BARIDHARA TAXI CORP",200
# "BARILLAS, RIGOBERTO",120
# "BARK TAXI INC",191
# "BARLISA CAB CORP",216
# "BARLO CAB CORP",187
# "BARMA TAXI INC",207
# "BARN TRANS CORP",206
# "BARNACLE TRANS CORP",118
# "BAROMETER HACKING CORP",232
# "BARON, STUART A.",95
# "BARREAU, WILFRID",90
# "BARRERA, GILBERTO",83
# "BARRERA,GERARDO",80
# "BARRERA,GLADYS",105
# "BARRETT, MILTON",94
# "BARRY & SAM INC",230
# "BARRY, VALLY E.",107
# "BARSOL CAB CORP",199
# "BART CAB CORP",216
# "BARTH MORRIS",82
# "BARTH TAXI, LLC",189
# "BARTHELEMY, ROSWAL",108
# "BARTHELUS & BARHTELUS INC",118
# "BARTHELUS,JOSEPH,M",85
# "BARTHOLD, SAUREL F.",119
# "BARTOLO, JOHN",109
# "BARUA, SHOVAN",112
# "BASDEO,DHANIRAM",89
# "BASE CAB CORP",334
# "BASE TRANSIT INC",214
# "BASEBALL TRANSIT INC",216
# "BASHARKEVICH,VECHESLAV",110
# "BASHIR SONS TRANS CORP",63
# "BASHIR,AHMED,GHULAM",88
# "BASILLO CAB CORP",196
# "BASKET CAB CORP",213
# "BASNYA TAXI INC",219
# "BASRA CAB LLC",38
# "BASS CAB CORP",174
# "BASSI BROTHERS INC.",105
# "BASSI, KULWANT SINGH",47
# "BASSI, RASHPAL S.",90
# "BASSI, SURINDERPAL SINGH",65
# "BASSI,MANJIT,SINGH",76
# "BASTIEN,MARC,C",112
# "BAT CAB CORP.",169
# "BAT ZION CAB CORP",183
# "BAT-YAM CAB CORP",230
# "BATAILLE, JEAN-PIERRE",86
# "BATCH-BOOTCH EXPRESS CAB CORP",193
# "BATESVILLE OPERATING CORP.",211
# "BATH CAB CORP",235
# "BATMAN TAXI INC",230
# "BATTERY TRANS INC",213
# "BATTS CAB LLC",19
# "BATURGIL ,SEVKI",80
# "BAUCICAUT,JEAN & DUPITON,SAMUEL",34
# "BAWA TAXI CORP.",38
# "BAWA,DILBAG",84
# "BAWA,PARLAD SINGH",83
# "BAWA,YUSIF",107
# "BAWNIK, JACK",100
# "BAXON TAXI CO. INC.",216
# "BAXTER CAB CORP",211
# "BAY OF BANGAL GROUP INC.",114
# "BAYACOUB,FAHMI",52
# "BAYDEN CAB CORP",222
# "BAYEV LLC",90
# "BAYONNE,JEAN ALIX",103
# "BAYONNE,JEANMARIE",51
# "BAZAR TAXI INC.",183
# "BAZELAIS,PIERRE,NMI",100
# "BAZIL, ROSELLE_& JEAN-LOUIS, JEAN L.",108
# "BAZILE,JEAN,H",115
# "BAZILE,WESNER",96
# "BAZILE,YVES",218
# "BBN TAXI LLC",191
# "BDETR HOLDING INC",213
# "BEA TAXI INC",167
# "BEACH CAB CORP",202
# "BEACH TRANS INC",210
# "BEASLEY TRANS INC",232
# "BEATA TRANSIT INC",214
# "BEATRICE, JEAN D.",101
# "BEATRICE,JAMES",95
# "BEATY, SUSAN, ANN",96
# "BEAU SERVICE CORP",280
# "BEAUBRUN,BERTHOLET",112
# "BEAUCHAMPS, PIERRE",119
# "BEAUJOLAIS TAXI INC",82
# "BEAUPORT, AXELLE",88
# "BEAUSEJOUR,NORIUS",66
# "BEAUTE, JEAN E.",112
# "BEAUTY CAB CORP",209
# "BEAUVAIS,JACQUES,Y",104
# "BEAUZILE, YVES",110
# "BEBO CAB CORP",291
# "BECK CAB CORP",293
# "BECRUX SERVICE LLC",114
# "BEDER, MEIR",107
# "BEDFORD TAXI LLC",221
# "BEDI,HARVINDER,P",90
# "BEDNAREK, TED",108
# "BEDROS YILDIZ",78
# "BEECH TRANS CORP",248
# "BEEL CAB CORP.",209
# "BEET CAB CORP",211
# "BEETHOVEN TRANSIT INC",213
# "BEETLE CAB CORP",204
# "BEGONIA TAXI INC",200
# "BEGOWAL, PARAMJIT, S.",72
# "BEGUM, RUKSANA",29
# "BEHAR, DANIEL",111
# "BEIN CAB CORP",327
# "BEJO CAB CORP",68
# "BELA CAB CORP",297
# "BELC,RYSZARD",104
# "BELGARDE,RAYMOND",100
# "BELIARD,LECLERC",108
# "BELIZAIRE, JACQUES P.",69
# "BELIZAIRE, JEAN-BAPTISTE",125
# "BELL TAXI CORP",319
# "BELLA HACKING CORP",299
# "BELLANTON,JEAN,F",109
# "BELLATRIX SERVICE LLC",143
# "BELLSKY TAXI LLC",209
# "BELMONT, FRITZBERT",1
# "BELROSE CAB CORP",217
# "BELVEDERE TAXI LLC",74
# "BEM CAB CORP",82
# "BEN GOR TAXI INC",207
# "BEN-AMI,NIRIT",108
# "BEN-BELLA TRANS CORP",224
# "BEN-GOR TAXI INC",108
# "BEN-KHE TRANS CORP",90
# "BEN-LEVY, AVNER",35
# "BENBAT CAB CORP",202
# "BENDEZU,ARTEMIO",106
# "BENDEZU,LUIS,A",87
# "BENE CAB CORP",333
# "BENGA,JUSTIN,Y",79
# "BENGAL TIGER YELLOW TAXI CORP.",134
# "BENGO TRANSIT INC.",134
# "BENHAROCHE, ARMAND",95
# "BENITES,VICTOR",81
# "BENITEZ, MANUEL",90
# "BENITEZ,LUIS,LOPEZ",19
# "BENJAMIN,RASCHELL",21
# "BENJAMIN,WILFRID",92
# "BENJI CAB LLC",7
# "BENKUN HACKING CORP",112
# "BENNETT,LAURENCE",84
# "BENOIT, JOSEPH C.",101
# "BENOIT, PAUL G.",107
# "BENOIT,LESLY",109
# "BENOIT,RALPH,A.",78
# "BENOIT,SERGE",89
# "BENSON HACKING CORP",196
# "BENTO TRANS CORP",198
# "BERARDELLI, BENITO A.",103
# "BERET CAB CORP",226
# "BEREZINSKY, LAZAR",41
# "BEREZKA CAB CORP",149
# "BERGEN CAB CORP",214
# "BERGER,LASZLO",83
# "BERH CAB CORP",125
# "BERIY, ARON",82
# "BERNAL, LUIS",101
# "BERNARD, LUC T",59
# "BERNARD, WESLEY",112
# "BERNARD,HUGUES",114
# "BERRY TAXI INC",245
# "BERRY, SYLVESTRE",124
# "BERWYN CAB CORP",21
# "BESI CAB CORP",321
# "BEST EXPRESS CAB CORP",197
# "BEST TAXI LLC",3
# "BEST YELLOW CAB CORP",219
# "BETA TRANS CORP",212
# "BETH CAB CORP",300
# "BETMAR EXPRESS CAB CORP",72
# "BETTS CAB CORP",228
# "BETTY TRANSIT, LLC",223
# "BEUL CAB CORP",334
# "BEVA CAB CORP",217
# "BEXLEY-EXETER INC",194
# "BEYDOUN,DEB,M",81
# "BEYEEMAN HACKING CORP.",109
# "BGW 2T21 LLC",34
# "BGW 4A27 LLC",28
# "BGW 5225 LLC",2
# "BGW 5E25 LLC",18
# "BGW 9T66 LLC",11
# "BGW I TAXI LLC",29
# "BGW II TAXI LLC",64
# "BGW III TAXI LLC",24
# "BHADDAR TRANSIT LLC",85
# "BHAG SINGH CAB CORP.",219
# "BHAGTANA CAB CORP",207
# "BHAI BHAI TAXI CORP.",123
# "BHAMRA,NIRMAL,S",112
# "BHANDAL,CHARANJIT,S",100
# "BHANDAL,GURNAM",111
# "BHANDARI,ARUN K & VIG,CARINA",96
# "BHANDARI,ASHWANI",100
# "BHANGU TAXI CORP.",114
# "BHARDWAJ TAXI LLC",102
# "BHARDWAJ,PARITOSH",88
# "BHARTH,AJIT,SINGH",98
# "BHATIA,BEN",3
# "BHATTI BROTHERS TAXI LLC",2
# "BHATTI,GURDEEP,SINGH",45
# "BHATTI,MUHAMMAD,J",103
# "BHATTI,QAISAR,A",54
# "BHATTI,SAJID,GHANI & AKHTAR,SHAHZAD",109
# "BHATTI,SANTOKH,S",111
# "BHATTI,SURJIT",102
# "BHAURA,BALVINDER,S",103
# "BHUIYAN CAB CORP",79
# "BHUIYAN, FOKHRUL, I",44
# "BHUIYAN, NASIR, U.",104
# "BHUIYAN,IFTEKHAR R.",108
# "BHUIYAN,WASHIM,U",122
# "BHULLAR, SUCHA & RAGHBIR",100
# "BIANA FRANCO CAB CORP",204
# "BIBI TAXI INC",218
# "BIDON, EDDY",116
# "BIEN-AIME,JEAN,W & JEAN,JOSEPH,A.D.",9
# "BIFAUS TAXI INC.",97
# "BIG APPLE CAB SERVICE LLC",53
# "BIG ARI TAXI CORP.",223
# "BIG AUBREY TAXI INC",223
# "BIG BOYS TAXI INC.",78
# "BIG D TRANSIT INC",225
# "BIG GULP HACKING LLC",253
# "BIG H.HACKING CORP",231
# "BIG JEFF CAB CORP",224
# "BIG JOHN CORP.",12
# "BIG NUMBERS CAB LLC",2
# "BIG RIVER TAXI,LLC",38
# "BIG ROBERTS TRANSPORTATION LLC",104
# "BIG SAM TAXI CORP",162
# "BIG TAXI LLC",102
# "BIKINI BOTTOM TAXI LLC",325
# "BIKRAM TRANSIT CORP.",107
# "BIL-EZ SERV CORP",225
# "BILIZA INC.",215
# "BILL TAXI INC",207
# "BILOS, ANGELE",107
# "BIMBO TAXI LLC",90
# "BIMER TAXI INC",223
# "BINYAMINOV,BINYAMIN",107
# "BIPAN & JOYA SARKER INC.",19
# "BIRD TAXI CORP",333
# "BIRD TRANS CORP",176
# "BIRDI,SARDARA",101
# "BIRK CAB CORP",20
# "BIRK,SUDAGAR,S",111
# "BISCO TRANSIT INC.",68
# "BISHOP K CAB CORP",209
# "BISLA,SUKHVIR,S. & SINGH,KULVIR",100
# "BISMARK TAXI CORP",211
# "BISMILLAH TAXI CORP.",75
# "BISON TRANS CORP",228
# "BISTA,SAMBHU",112
# "BISWAS TAXI LLC",102
# "BISWAS,BIDHAN",100
# "BISWAS,NOOR,M",110
# "BITA,ION",121
# "BITSY TRANSIT INC",62
# "BITTERROOT HACKING CORP",86
# "BJ CAB CORP.",70
# "BLACK FOREST TAXI,LLC",59
# "BLACK LABEL TAXI LLC",75
# "BLACKOUT HACKING CORP",195
# "BLAISE,CEMERITE,J",111
# "BLAISE,RENE,ROY",119
# "BLANARU, GRIGORE",31
# "BLANC, ARNAULD",111
# "BLANC, SYLVEUS",24
# "BLATT, ADOLF",107
# "BLEND TRANSIT LLC.",201
# "BLESS CAB CORP",325
# "BLESSED CAB CORP",201
# "BLIDARIU,NICOLAE",77
# "BLISS CAB CORP",215
# "BLITZ TRANSIT INC",230
# "BLITZER, JUDI",97
# "BLIZZARD CAB LLC",5
# "BLOT, AUDAIN",73
# "BLUE CAB CORP",328
# "BLUE CLOUD TRANS INC.",237
# "BLUE EYE ALEX LLC",84
# "BLUE HAWAII TRANSPORT LLC",113
# "BLUE LAD TAXI LLC",37
# "BLUE NEPTUNE CAB LLC",28
# "BLUE SKY HACKING INC.",320
# "BLUE TRANSIT INC",231
# "BLUEBERRY CAB LLC",71
# "BLUESEAS TRANSPORTATION LLC",114
# "BLUETICK CORP.",102
# "BLUM,STANLEY",55
# "BOAHEN,FRANK & ASARE,GEORGE,L",94
# "BOAR TAXI INC",191
# "BOATENG,GEORGE & BOATENG,GEORGINA",78
# "BOB'S TAXI CORP",113
# "BOBAKI CAB CORP",173
# "BOBBY CAB CORP",203
# "BOCHEVER, MARK",119
# "BODIT TAXI CORP",58
# "BODY SLAM TAXI LLC",82
# "BODZWA,MICHAEL",111
# "BOGAZ TAXI INC.",124
# "BOGEY SERVICE CORP.",215
# "BOGGS TRANSIT INC",217
# "BOGIN, YEVGENY/CHIZHIK, IRINA",83
# "BOLIVAR TAXI, LLC",217
# "BOLLA TAXI INC",200
# "BOLOGNA, JOSEPH",109
# "BOLOVIS, DIMITRIOS A.",101
# "BOMBAY TAXI CORP",33
# "BOMBSHELL TAXI LLC",83
# "BONANZA OPERATING CORP",223
# "BONAO TAXI INC",201
# "BONCUKCU,SALIH",94
# "BONEHEAD LLC",204
# "BONGA CAB CORP",222
# "BONGO BONDU CAB CORP",203
# "BONHOMME, SERGE",114
# "BONILLA, SANTIAGO",110
# "BONITA HACKING CORP",201
# "BONNA,PAT",86
# "BONNY, FRANK",74
# "BONNY, HERNTZ",84
# "BONNY, NESLY",89
# "BONNY,SERGE,T",96
# "BONSU,ADDAI",111
# "BONTEMPS, VICTOR",109
# "BOO BOO KITTY HACKING CORP.",185
# "BOONKAI, JERAVOOT",7
# "BOPARAI,BALJINDER",73
# "BOR EXPRESS CAB CORP",213
# "BORDEAUX TAXI INC.",78
# "BORDER CAB CORP.",185
# "BORELLA CAB INC.",234
# "BORGA TAXI INC.",113
# "BORGES, BENJAMIN",105
# "BORICUA HACKING CORP",107
# "BORIS TRANS INC",219
# "BORISOVSKIY,FOMA",113
# "BORNSTEIN,DAVID",35
# "BOROCHIN,MARAT",74
# "BOROWICKI,ZBIGNIEW",117
# "BOSS TAXI, LLC",206
# "BOSTANIAN,VARUJAN,D",109
# "BOTAIL TRANS LLC",98
# "BOTTEX, JOAN & ETIENNE",110
# "BOUABIDI, OMAR",104
# "BOUCARD,CARILUS",56
# "BOUCHEKOUK,ALI",52
# "BOUCICAUT, YVON",103
# "BOUKANI,FARHAD,MOHAMMAD",129
# "BOUKERCHE,MOHAMED",117
# "BOULAS, GEORGIOS",97
# "BOULIS LLC",120
# "BOULOS TAXI CORP.",231
# "BOURBON TAXI LLC",51
# "BOURDEAU, JEAN",100
# "BOUSAID,BAHIJ",108
# "BOUTSOLIS, CHRISTOS",86
# "BOUTSOLIS,ANASTASIA",87
# "BOUZOUKIA LLC",207
# "BOX CAB CORP",223
# "BOYAJIAN, GEVORK",113
# "BOYAL, KASHMIR",83
# "BOYD TAXI INC",326
# "BOYNTON TRANSPORTATION CORP",212
# "BRABUS SERVICE CORP.",193
# "BRACHA CAB CORP",222
# "BRADLEY CAB CORP",226
# "BRAICH, BALDEV KAUR",86
# "BRAICH, BALDEV S.",94
# "BRAICH, GURDEV S.",101
# "BRAICH, PRITAM S.",95
# "BRAICH, SUKHVINDER S",111
# "BRAICH,JAGJIT S & BRAICH,GURJIT S",84
# "BRAKE TRANS CORP",198
# "BRAN TAXI INC.",198
# "BRAN, CORNEL",126
# "BRAN, ILIE",117
# "BRANA HACKING CORP",199
# "BRANDON TAXI, LLC",202
# "BRANDY OPERATING LLC",50
# "BRANT SERVICE CORP.",157
# "BRANT TAXI INC",226
# "BRAR CAB LLC",9
# "BRAR, GURDIP S.",123
# "BRAR,GURMEET SINGH",102
# "BRAS CAB CORP",294
# "BRATISHKA TAXI INC.",203
# "BRATSZTEIN, BERNARD",117
# "BRAUNSTEIN, ALICE",1
# "BRAZ HACKING CORP",221
# "BRCR LLC",71
# "BREA CAB CORP",202
# "BREB CAB CORP",324
# "BREEG TAXI CORP.",193
# "BREEZE'S CAB CORP",211
# "BREFO,KOFI",21
# "BREITLING TAXI INC",226
# "BRENT CAB CORP",200
# "BREONNA-CHRISTINE OF NEW YORK LLC",219
# "BRESIER, LELIO & JEANNE",97
# "BRETON,YVES",102
# "BRETOUS, HARRY",93
# "BRETOUX, CLAUDE",61
# "BREWER TAXI CORP",173
# "BRFR CORP.",21
# "BRH,INC.",102
# "BRIAND,NICOLE",118
# "BRIANS EXPRESS CAB CORP",221
# "BRIDGETTE TRANSIT LLC",240
# "BRIFIL,GARY",115
# "BRIGHT CAB LLC",51
# "BRIGHTNESS CAB CORP",186
# "BRIGITTE CAB CORP",188
# "BRIGNOL,JEAN-PRICE",115
# "BRINI TRANSIT INC.",169
# "BRISARD, EDGARD",107
# "BRISSETT, NORMAN E.",114
# "BRISTOUT, LOUIS",105
# "BRIT CAB CORP",213
# "BROAD OAK CAB,LLC",61
# "BROADWAY CAB CORP.",231
# "BROGUN, DMITRY",121
# "BROMARK SERVICE CORP",290
# "BRONFELD, MICHAEL",97
# "BRONOPOLSKY, BORIS",25
# "BRONSTEIN,SIMON",74
# "BROOKE CAB CORP.",209
# "BROOKLYN CAB CORP",94
# "BROOKLYN KNIGHTS TRANS INC.",241
# "BROOKLYN TAXI LLC",26
# "BROOKS, HARVEL",105
# "BROOKSJOY LLC",200
# "BROWER,SONNY",117
# "BROWN, HUBERT S.",114
# "BROWN, MELVIN R.",104
# "BROWN, ZIPORA AND OBERHARD, JODI",84
# "BROWNE, EDWARD",87
# "BROWNIE OPERATING LLC",51
# "BROWNIE TAXI LLC",90
# "BROZ TRANS LLC",122
# "BRRC LLC",62
# "BRUNACHE,JEAN,C",113
# "BRUNEL PAUL & CHRISLORME PAUL",114
# "BRUNO TAXI CORP.",199
# "BRUX CAB CORP",324
# "BRYANT TRANS INC",204
# "BRZOZOWSKI,DARIUSZ",117
# "BTMG CAB CORP",189
# "BTR TAXI INC",232
# "BUBBA OPERATING LLC",40
# "BUBBY BUBBY TAXI INC",194
# "BUBBY CAB CORP.",38
# "BUBER,EFIM",90
# "BUCCANEER TAXI INC",205
# "BUCK L. CHIN",33
# "BUCK TAXI INC",150
# "BUCK TRANSIT INC.",202
# "BUCKO CAB INC.",220
# "BUCUR EXPRESS CAB CORP",219
# "BUDD TAXI CORP",317
# "BUDDYS CAB CORP",213
# "BUFFALO BILL TAXI INC",221
# "BULIBASS TAXI INC",199
# "BULKIN,ARKADY",103
# "BULLET CAB CORP",221
# "BULLET OPERATING LLC",44
# "BULLOCK,ANNA,MAE",67
# "BUMBLEBEE TAXI LLC",12
# "BUNKY CAB CORP.",112
# "BUNTY & JYOTI INC.",198
# "BUNY EXP CAB CORP",199
# "BURACCA CAB CORP",230
# "BURD, LEO",110
# "BURGOS, ALEXANDER",94
# "BURGOS, ROBERTO",95
# "BURGOS,JORGE,G",91
# "BURMAN EXPRESS CAB CORP",209
# "BURSA CAB CORP",210
# "BURSHTEYN, YEFIM",94
# "BURSHTEYN,NATALYA",105
# "BUSTER CAB CORP.",190
# "BUSY CAB CORP.",35
# "BUTEAU,JEAN,R",125
# "BUTT, ARIF,H",110
# "BUTT,FAISAL",64
# "BUTT,IMRAN",58
# "BUTT,IQBAL",88
# "BUTT,MOHAMMAD,SARWAR",111
# "BUTT,MOIEN",26
# "BUTT,NADEEM",113
# "BUTTACAVOLE,BEATRICE",97
# "BUTTAR TAXI LLC",82
# "BUTTERFLY TAXI LLC",44
# "BUTTERSCOTCH TAXI LLC",103
# "BUTTIGIEG, JOSEPH & CAUCHI,JOHN",110
# "BUTWIN TRANSIT INC",120
# "BVA CAB CORP.",110
# "BY1940 LLC",48
# "BYBLOS TAXI INC",71
# "BYNUM FAMILY TAXI LLC",58
# "BYNUM, DAVID",17
# "BYRON O TAXI INC",232
# "C & E CAB CORP",215
# "C & K TAXI CORP",104
# "C & R BHOGAL, LLC",96
# "C J CAB CORP",218
# "C R S CAB CORP",233
# "C&V TAXI INC.",49
# "C'EST MOI TAXI INC",183
# "C. G. TRANS CORP",193
# "C.B.A. GROUP LLC",25
# "C.B.E. CAB CORP",219
# "CABA, LUCIAN",125
# "CABBO SERVICE CORP",312
# "CABLE CAB CORP",348
# "CABREJOS,GUSTAVO,E",122
# "CABRERA, EDUARDO M.",94
# "CABRERA,CARLOS,E",100
# "CABRERA,SERGIO",116
# "CABRINI TAXI LLC",67
# "CACERES, JOSE, E.",5
# "CACERES, SERGIO_& VACA,JAVIER",102
# "CACERES,JAIME,P",79
# "CACERES,LUIS",82
# "CADDIE SERVICE CO. INC.",241
# "CADEAU,JEAN,H",17
# "CADET, JEAN C",95
# "CADET,FELIX",116
# "CADET,PIERRE L.",123
# "CADOGAN TAXI CORP",228
# "CAFE SERVICE CO INC",232
# "CAGEN, BURTON",110
# "CAGEN, LARRY",102
# "CAGEN, MICHAEL",101
# "CAGEN,BARBARA,G",95
# "CAGEN,HOWARD,PAUL",89
# "CAIN TAXI INC",290
# "CAINES, JOHN R.",107
# "CAJAMARCA,RAMON,A",96
# "CAJUSTE, JEAN-BAPTISTE, A",98
# "CAJUSTE, LUC R.",120
# "CAJUSTE, MICHEL",112
# "CAJUSTE,ERBY",62
# "CAJUSTE,GERALD",80
# "CALAFATE LLC",80
# "CALANIT SERVICE CO INC",198
# "CALCIUM ONE SERVICE INC.",196
# "CALDERON,ANDRES,N & KIS KANDISSE C",105
# "CALICO CAB CORP",160
# "CALIXTE, JEAN",117
# "CALIXTE, RODNEZ/SANON, JACQUES",88
# "CALIXTE,LOUIS,E",96
# "CALL A CAB CORP",187
# "CALL FIRST TAXI, LLC",83
# "CALLE,RAFAEL,A",72
# "CALRO TRANS INC",86
# "CALVADOS TAXI LLC",68
# "CALVANICO LLC",114
# "CALVARY HACKING CORP",241
# "CALVIN CAB CORP.",87
# "CAMAC CAB CORP",215
# "CAMEAU, SERGE",101
# "CAMEL TRANS CORP",330
# "CAMELOT TAXI INC",231
# "CAMILLERI, EUGENIO",103
# "CAMILLERI, RAYMOND",73
# "CANADAS TAXI INC",220
# "CANAGAT CAB CORP",210
# "CANARY TRANS CORP",88
# "CANDE TAXI INC.",215
# "CANDIA, ROLANDO",95
# "CANDY APPLE TAXI LLC",54
# "CANINE TRANS CORP.",142
# "CANIZARES, LUIS A.",94
# "CANNES TAXI INC",68
# "CANNEY CAB CORP.",118
# "CANNON,PAUL,L",92
# "CANO TAXI INC",212
# "CANO,RODRIGO",97
# "CANOPUS SERVICE LLC",116
# "CANTILI, MARIOARA",106
# "CANTILI,ROMULUS,C",103
# "CANTON TAXI CORP",209
# "CAO,HA,VAN",113
# "CAPRI TAXI CORP",235
# "CAPRIC, TAHIR",108
# "CAPTAIN OPERATING CORP",208
# "CARA TAXI INC",214
# "CARAMEL TAXI LLC",100
# "CARB TRANS CORP.",181
# "CARBAJAL,CARLOS,I",96
# "CARBALLA CAB CORP",213
# "CARBALLEIRA, FRANK",94
# "CARBALLO,HERNANDO",113
# "CARBON TRANS CORP",198
# "CARD TRANS CORP",211
# "CARDONA, HIRAM",83
# "CARDONA, NORBERTO",113
# "CAREFREE CAB CORP",98
# "CARIGONAT CAB CORP",240
# "CARLA CAB CORP",220
# "CARLED CAB CORP",189
# "CARMONA,MARIO,G",96
# "CARNELIAN CORP.",97
# "CAROLINA TAXI INC",329
# "CAROU,DANIEL,H",108
# "CARP SERV CO. INC",231
# "CARRASCO, VICTOR",34
# "CARRERA TAXI INC",101
# "CARRERA, VICTOR",111
# "CARROT LLC",47
# "CARSON TAXI CORP",205
# "CART CAB CORP",217
# "CARTIER TAXI INC.",77
# "CASEMA TRANSIT INC.",235
# "CASHEW CAB CORPORATION",134
# "CASHMERE CAB CORP",164
# "CASIMIR, JEAN",50
# "CASIMIR, ZULKA",56
# "CASIMIR,ALCIDE",78
# "CASMART TRANSIT INC.",112
# "CASSEUS, EDOUARD",56
# "CASSEUS, FREDZER",97
# "CASSEUS, JEAN-ROBERT",91
# "CASTELLANOS,JESUS,M & EDWARD,M",101
# "CASTILLO, MIGUEL ANGEL",102
# "CASTRO & SHEA INCORPORATED",115
# "CASTRO,CARLOS",103
# "CAT BOY HACKING CORP.",178
# "CAT TAXI CAB,LLC",62
# "CATCH A TAXI LLC",239
# "CATE TRANSIT INC",206
# "CATERING SOLUTIONS INC.",94
# "CATERPILLAR CAB,LLC",93
# "CATIN,GERARD,F & DOR,MARIE",77
# "CATON TRANS INC",241
# "CATORCE HACKING CORP",208
# "CAYEMITTE, GERARD J.",112
# "CAYO,CESAIRE",110
# "CAZEAU,M & JEAN-PHILIPPE,F",97
# "CD83 LLC",51
# "CDA LEGACY INC.",113
# "CEBER CAB CORP.",216
# "CEDE TAXI INC",223
# "CEDENO,VIRGINIA",95
# "CEDUNA CAB CORP",200
# "CEG CAB CORP",206
# "CELEBI,LATIFE",4
# "CELERINO, BERNARDO J",97
# "CELESTIN, ROLAND",75
# "CELESTIN,ABEL & CELESTIN,FRANGY",123
# "CELESTIN,FRITZ",112
# "CELESTIN,ROSSINI,F",86
# "CELESTINE TAXI INC",226
# "CELK SERVICE CORP",275
# "CENAT, JEAN FELIX",52
# "CENTER BLVD P LLC",41
# "CENTER TRANS INC",218
# "CENTRAL CAB LLC",50
# "CENTRAL HACKING CORP",197
# "CENTURY AGAMI CAB LLC",213
# "CERTAIN SERVICE CO INC",193
# "CESAIRE, FLOBERT",69
# "CFN CAB CORP",214
# "CHA-CHA HACKING CORP",214
# "CHABER TAXI CORP",203
# "CHABLIS CAB CORP",216
# "CHACKO,PHILIPOSE",117
# "CHAGGAR,TIRATH,S",103
# "CHAGIT CAB CORP",223
# "CHAHAL & NAHAL LLC",89
# "CHAHAL,DALJIT,SINGH",112
# "CHAHINE, MOHAMED Y.",99
# "CHAI TAXI INC",245
# "CHAI,IHN-CHEOL",131
# "CHAIKEN, JACKIE, L.",68
# "CHAIMY, SCHLOMO",116
# "CHAKRABORTY, MILAN",81
# "CHALKIDIKI TAXI INC",212
# "CHALKIS CAB CORP",209
# "CHAMISHE CORP",221
# "CHAMKOR CAB CORP",79
# "CHAMONIX TAXI LLC",85
# "CHAMPAGNE,JEAN CLAUDE",47
# "CHAMPION AGAMI CAB LLC",237
# "CHAMPION OPERATING LLC",45
# "CHAN SERVICE CO INC",220
# "CHAN, CHI,TAT",11
# "CHAN, DANNY",212
# "CHAN, MICHAEL,SAI HO",101
# "CHAN, NELSON",12
# "CHAN, RICHARD S.",115
# "CHAN,BENNY,C,P",104
# "CHAN,CHI,KWONG",114
# "CHAN,JOHNNY,S",115
# "CHAN,KAI,MING",104
# "CHAN,KIN",71
# "CHAN,KIN,WA",92
# "CHAN,KWOK,CHUNG",112
# "CHAN,KWONG F.",86
# "CHAN,SING-FAI",23
# "CHAN,TAI,YA",115
# "CHAN,WING",91
# "CHAN,YUEN,CHUEN",109
# "CHAND CAB CORP.",17
# "CHAND,KAUR",108
# "CHAND,PREM",26
# "CHANDER,GIRISH",99
# "CHANDER,LOVELEEN",74
# "CHANDRA PARA CAB CORP",203
# "CHANEL CAB CORP",203
# "CHANG, MICHAEL",90
# "CHANMYAE LLC",30
# "CHANNA AND SINGH TAXI CORP",103
# "CHANNAN,CARL,H.",101
# "CHANNELS CAB CORP",109
# "CHAPEL TRANS INC",188
# "CHAPPELL,LUCY,LUCILLE",100
# "CHAPTER TWO HACKING CORP.",195
# "CHAPUSETTE, ALBERT",85
# "CHARDONNAY TAXI INC.",67
# "CHARGING BULL TAXI LLC",211
# "CHARITABLE,MERCIUS",96
# "CHARITABLE,RENOLD,J",89
# "CHARLEMAGNE, JEAN A.",6
# "CHARLES, ANTOINE",93
# "CHARLES, FIGNOLE",89
# "CHARLES, FRANCOIS",104
# "CHARLES, FRANTZ D",103
# "CHARLES, FRELIOR",74
# "CHARLES, HENRY CLAUDE",83
# "CHARLES, JEAN-CLAUDE",59
# "CHARLES, JOSEPH W.",29
# "CHARLES, MARC B.",94
# "CHARLES,ANATHAS,A",77
# "CHARLES,AUDMAR",23
# "CHARLES,AUGUSTIN",75
# "CHARLES,CYNTHIA,M",95
# "CHARLES,JEAN,SAMSON",115
# "CHARLES,MARIE D",102
# "CHARLES,OSNER",92
# "CHARLES,WILBERT",111
# "CHARLES-MARC, JEAN C.",77
# "CHARLIE HACKING CORP",208
# "CHARLITE, JEAN-CLAUDE",90
# "CHARLITTE, JEAN, P.",139
# "CHARLOTTE CAB CORP",215
# "CHARTELAIN, MAX",71
# "CHATTHA, MOHAMMAD&CHATTHA NASAR",111
# "CHATTOO,NARASE",91
# "CHATTOO,RAMESAR,R",105
# "CHATTOO,SURESH & INDRA",111
# "CHAU,DO HANG",105
# "CHAUDHARY,MOHAMMAD,A",96
# "CHAUDHARY,PERVEZ,A",120
# "CHAUDHRY I. AHMED AND IMRAN LATIF",15
# "CHAUDHRY TRANSIT LLC",19
# "CHAUDHRY Z AHMED & SAJIDA AHMED",116
# "CHAUDHRY, AMTUL",20
# "CHAUDHRY,HAFIZ,UR",23
# "CHAUDHRY,IRSHAD M.&RAMZAN,MOHAMMAD",88
# "CHAUDHRY,LIAQAT,A",47
# "CHAUDHRY,MUHAMMAD,J & CHAUDHRY,MOHAMMAD,J",54
# "CHAUDHRY,NISAR,KHAN",84
# "CHAUDHRY,SAJJAD,J",95
# "CHAUDHRY,SAKHAWAT,A",106
# "CHAUDHRY,SAMI & IQBAL,MUZAFAR",62
# "CHAUDHRY,SIRAJ,UDDIN",104
# "CHAUDHRY,TANVEER,A",113
# "CHAUDRY,SHAFA,ULLAH",108
# "CHAUDRY,TARIQ,J & CHOUDHRY,ABBAS,G",15
# "CHAUDRY,ZAFAR,A",113
# "CHAUHAN,BALVIR",120
# "CHAVEZ, MIRNA",116
# "CHAVEZ,FREDDY,H",19
# "CHAWKI,JOHN,A",103
# "CHAWKI,MICHAEL",51
# "CHAWLA, AMARJIT, S.",105
# "CHAYA,GAZI",74
# "CHAZ CAB CORP",202
# "CHAZEN, SHELDON",113
# "CHECHELNITSKY, PYOTR",104
# "CHECK TRANS CORP.",225
# "CHECKER JOBS LLC",74
# "CHECO CAB CORP",212
# "CHEE CORP.",216
# "CHEE WAI WONG",75
# "CHEEKY TRANSIT LLC",213
# "CHEEMA BROTHERS CAB LLC",93
# "CHEEMA TRANS CORP",230
# "CHEERS CAB LLC",47
# "CHEF CAB CORP",334
# "CHEGINI, FARZIN",107
# "CHELSEA CAB CORP",317
# "CHEN, YEE, SUN",120
# "CHEN,ANDREW",105
# "CHEN,JIN,CHENG",114
# "CHEN,MAY,CHING",102
# "CHEN,PHILLIP,CHENG,HSUING",46
# "CHEN,QUAN",125
# "CHENAB LLC",25
# "CHENG, HERMAN",88
# "CHENG, JOSEPH",132
# "CHENG,PANG",113
# "CHENG,ROBERT",106
# "CHENG,RUEY-JONG",103
# "CHEONG, U HOU",104
# "CHEONG,HI,KAI",106
# "CHEONG,U-CHIO",106
# "CHERENFANT,JEAN-BAPTISTE",121
# "CHERENFANT,SERGE",101
# "CHERFILUS,MARIE",89
# "CHERILUS, CARLO J.",110
# "CHERILUS,EMMANUEL",92
# "CHERILUS,FRANCOIS",121
# "CHERUBIN, CHARLES",78
# "CHERUBIN,JEAN-LESLY",116
# "CHERWIN TAXI CORP.",206
# "CHERY, ERNEST",80
# "CHERY, JEAN, M.",103
# "CHERY,ERWICH",122
# "CHERY,JEAN,R",110
# "CHERY,LAVILAIRE",104
# "CHERY,PIERRE",55
# "CHERY,PIERRE,G",67
# "CHERYL TAXI CORP",223
# "CHESKY TRANSIT CORP",213
# "CHESTER CAB CORP",1375
# "CHESTER OPERATING LLC",43
# "CHEUNG,CHI,K",97
# "CHEUNG,KIM,K",118
# "CHEUNG,KIN,MING",98
# "CHEUNG,KWOK,CHUNG",23
# "CHEUNG,MAN",119
# "CHEUNG,WAI,KING",83
# "CHIANTI TAXI LLC",79
# "CHIBBARO,FRANCESCO",112
# "CHICAGO-NY PERFECT CORP",184
# "CHICKLA SERV CORP",110
# "CHICKLA SERVICE CORP",106
# "CHIEF CAB CORP",207
# "CHIEF SERVICE CO. INC.",237
# "CHILDREN OPERATING CORP",227
# "CHILINGARYAN,GEVORK",98
# "CHIN, YUET, GOON",15
# "CHIN,BUCK,K",81
# "CHIN,WAIN,H",116
# "CHINA TOWN TAXI LTD.",196
# "CHINGAS, ASIMINA",121
# "CHINGRIS TRANSIT INC",215
# "CHIPPY TAXI LLC",231
# "CHIPS AHOY TAXI LLC    R",95
# "CHIPS AHOY TAXI LLC",117
# "CHIRE TAXI INC",214
# "CHISET LLC",99
# "CHITA CAB CORP",144
# "CHIU,MING,SHING",105
# "CHIU,MO,MING",84
# "CHIU,SZE,FAT",126
# "CHO-SICA HACKING CORP",239
# "CHOCOLATE MOUSSE CAB CORP",229
# "CHOHAN,MANDEEP,S",111
# "CHONA TRANSIT INC",332
# "CHONG, GILBERT",82
# "CHONG, SOE,LI",110
# "CHOPARD TAXI INC",62
# "CHOPIN TRANSIT INC",214
# "CHOPPER TAXI INC",216
# "CHOPRA,MALKIT,S",100
# "CHORNOMOR SERVICE CO INC",203
# "CHOUDARY,SHABBIR,A",2
# "CHOUDHARY,SAQLAIN,H & CHOUDHARY,RIZWAN,U",102
# "CHOUDHRY, AMJAD ALI",112
# "CHOUDHRY,KARAMAT,A",119
# "CHOUDHRY,MOHAMMAD,I",102
# "CHOUDHRY,SAEED A",67
# "CHOUDHRY,SHAKEEL",94
# "CHOUDHURY, MAHBUB & CHOWDHURY,ZAHID",111
# "CHOUDHURY, MOKBUL",106
# "CHOUDHURY, SHAHADATH",101
# "CHOUDHURY, SHAUKAT",114
# "CHOUDHURY,AKIKUR,R",103
# "CHOUDHURY,ASHIF",68
# "CHOUDHURY,MAHBUB",117
# "CHOUDHURY,MOHAMMED,I",112
# "CHOUDHURY,MOUSUF,A",110
# "CHOUDHURY,OYES",121
# "CHOUDHURY,SHERWAN,A",37
# "CHOUDRY,MUSHTAQ",2
# "CHOW SERVICE CO INC",234
# "CHOW,KENNY",66
# "CHOW,RICHARD,Y",102
# "CHOW,THOMAS KWAN",80
# "CHOW,YU,MEIN",90
# "CHOWDHOURY, MASUD",76
# "CHOWDHURY, FAZLE A.",95
# "CHOWDHURY,ABDUL M.",117
# "CHOWDHURY,ABWABUL,A",105
# "CHOWDHURY,AHMED",108
# "CHOWDHURY,AINUL,K",109
# "CHOWDHURY,FIROZ",124
# "CHOWDHURY,GONESH,N & DAS,SAMVO,CHANDRA",106
# "CHOWDHURY,GULAM K & KHAN,ABDUL M",97
# "CHOWDHURY,ISMAIL& CHOUDHURY,FAZAL",89
# "CHOWDHURY,KABIR,AHMED",116
# "CHOWDHURY,LITON",105
# "CHOWDHURY,MOHAMMED,E,H",94
# "CHOWDHURY,MOHAMMED,M,R",114
# "CHOWDHURY,MOHIBUL,ALAM",103
# "CHOWDHURY,MOTIUR,R.",83
# "CHOWDHURY,NURUS,SAMAD",91
# "CHOWDHURY,NURUZZAMAN & ISLAM,YOUSUFUL",111
# "CHOWDHURY,RIPAN A",89
# "CHOWDHURY,SIRAJUL,I",107
# "CHOWDHURY,TAREK",110
# "CHOWDHURY,ZOKI,U & KOYESH,A",45
# "CHOWDRY,NASHER",4
# "CHRIS CAB CORP",200
# "CHRISANTHOS INC",215
# "CHRISGIOTA TAXI INC",214
# "CHRISOLOURIS,MICHEL",109
# "CHRISS TRANS INC",223
# "CHRISTIAN CAB CORP",233
# "CHRISTOS JI CAB CORP",197
# "CHRISTOS KAY INC",210
# "CHRISTOU, VASILIOS",126
# "CHROME TAXI SERVICE INC",218
# "CHRONOMETRON CAB CORP",236
# "CHRYSOULA TAXI INC",221
# "CHRYSOVALANTOU CORP,",99
# "CHRYSOVALANTOU CORP.",101
# "CHU,BENJAMIN",107
# "CHU,CHE,KWONG",34
# "CHU,CHEMING",105
# "CHU,MO,CHUNG",93
# "CHUDERY,KHAN,A",109
# "CHULON CAB CORP",206
# "CHUN, DAVID M.",126
# "CHUNG,CHUC,VAN",98
# "CHUNG,OK,YOUNG",82
# "CHUNKY TRANSIT INC",143
# "CHUNNU,ANWARUL,I",101
# "CHUOXER LLC",206
# "CHUPENKO YANINA/ADM EST OF CHUPENKO,IGOR",112
# "CIDELCA,BERTHONIER",109
# "CILEN,ERROL",83
# "CILIEN, ELLIOT",95
# "CILTEC SERVICE CORP",209
# "CIOMO, CAROLINE",33
# "CIPOLLONE,FRANK",118
# "CIPOLLONE,MADELINE",114
# "CIPUTRA,FRANKY",60
# "CIR CAB CORP",312
# "CIRCLE CITY CORP",193
# "CIRCUIT CAB CORP",197
# "CIRRUS HACKING CORP",235
# "CISSE,ALASSANE",118
# "CIT CAB CORP",220
# "CITATION CAB CORP",236
# "CITICAR CAB LLC",6
# "CITY BOYS CORP",168
# "CITY EXPRESS CAB CORP",155
# "CITY LIMITS CORP.",212
# "CITY TAXI CAB,LLC",54
# "CITY TAXI MANAGEMENT, LLC",7
# "CIV CAB CORP",235
# "CIVIL,MILIO",101
# "CJA GRIGORAS BROS.INC.",110
# "CLAIR,SUSAN,J",100
# "CLAM TRANS CORP",214
# "CLARA LUDMILA CAB CORP",8
# "CLARKE,DELROY",117
# "CLARKE,HERMAN,D,JR",117
# "CLARKE,MARK ANSLEY",17
# "CLARON TAXI CORP",203
# "CLASS TRANSIT INC",228
# "CLAUDE CAB CORP",123
# "CLAUDE,YVES & ISRAEL,JEAN",88
# "CLAUDETTE TAXI, L.L.C.",182
# "CLAUTAIRE, SANON",101
# "CLEAN SERVICE CO. INC.",199
# "CLEAR SERVICE CO INC",241
# "CLEMENT, PIERRE",76
# "CLEOPATRA CAB CORP",228
# "CLEOPHAT, DELAND",102
# "CLERGE, JOSEPH",102
# "CLERMONT,FRANCOIS",137
# "CLERVOYANT, MADSEN",112
# "CLETI SERVICE CORP",213
# "CLEVER TAXI INC",235
# "CLIFF CREST LLC",43
# "CLIFF ST TAXI CORP.",95
# "CLIFFORD TAXI SERVICE, INC.",202
# "CLIFTNEL LLC",122
# "CLIMB SERVICE CO. INC.",210
# "CLOCK TRANS CORPORATION",201
# "CLORINDA TRANSIT INC",195
# "CLOSTER TAXI, LLC",244
# "CLOZEUS, CRESCENT",116
# "CLUMBER TRANS CORP",210
# "CLYDE CAB CORP",1386
# "CMC TRANSIT LLC",83
# "CMCC DELTA LLC",73
# "COACHMAN TAXI INC",328
# "COBALT SERVICE CO INC",211
# "COBOS,AMANDA",109
# "COBRA TAXI INC",221
# "CODY SERVICE CO INC",208
# "COFFER SERVICE CO INC",231
# "COFI BOAT CORP.",76
# "COGNAC TAXI LLC",81
# "COHEN, MARGALIT",103
# "COHN, EDWARD",104
# "COICOU,EMMANUEL",106
# "COIMIN, WILNER",100
# "COIN CAB CORP",190
# "COISMAIN, JEAN",101
# "COLAS, JOSEPH",51
# "COLBY CAB CORP",225
# "COLD SPRING TAXI LLC",209
# "COLE CAB CORP",220
# "COLELLA, GIUSEPPA",103
# "COLFUN TAXI CORP",107
# "COLIN BEAUGE",10
# "COLIN, AUGUSTIN",107
# "COLLADO, ANDRES",74
# "COLLEGE POINT TAXI INC",191
# "COLLEGIATE CAB CORP",201
# "COLLIN & DACIS CAB CORP.",84
# "COLLINS CAB LLC",41
# "COLON GROUP LLC",102
# "COLON, EDUARDO",103
# "COLONIAL CAB CORP",216
# "COLOPELNIC, MIHAI",109
# "COLOSEO LLC",73
# "COLT TAXI INC",344
# "COLUMBIA AGAMI CAB CORP",199
# "COLUMN CAB CORP",208
# "COMER TAXI INC",217
# "COMMANDER OPERATING CORP",199
# "COMMISSION CAB CORP",218
# "COMPLETE CAB CORP",213
# "COMPLETE TRANS LTD",222
# "COMPLEX SCHEDULE CAB CORP",183
# "COMPOSITE TRANSIT LLC",220
# "COMPOTE CAB CORP.",85
# "CONCE,JOSE,LUIS",98
# "CONCON INC.",104
# "CONCORDE CAB CORP",305
# "CONCOURSE CAB CORP",204
# "CONDO TAXI INC.",194
# "CONILLE,EMMANUEL",108
# "CONMUR CAB CORP",304
# "CONSENT CAB CORP",213
# "CONSET TRANS INC",218
# "CONSTANCE CAB CORP",193
# "CONSTANCE CORP",216
# "CONSTANTINOS & NIKOLAOS CAB INC",222
# "CONTI, VICTOR",107
# "CONTINUED CAB CORP",242
# "CONTON CAB CORP.",216
# "COOKIE CAB CORP",206
# "COOL CAB CORP",224
# "COPPER ONE CAB CORP",232
# "CORA HACKING CORP",201
# "CORASON CAB CORP",171
# "CORCOVADO CAB CORP.",199
# "CORIOLAN, HENRICK",97
# "CORLEAR CAB CORP",99
# "CORNELIA TAXI LLC",49
# "CORNELL CAB CORP.",204
# "CORNETTA, HAROLD, J",83
# "CORONAMOS CAB CORP",147
# "CORREA, MARIO",99
# "CORSI CAB CORP",199
# "COSMAY, MEPRIUS S.",86
# "COSMO TAXI EXPRESS CORP",83
# "COSTEA, COSTEA",109
# "COSTELLA CAB CORP.",129
# ...
# "TULCI 14 LLC",124
# "TULIP TRANS CORP",226
# "TULSA CAB CORP",213
# "TULYA KOGAN ASSOCIATES INC",280
# "TURBO TAXI INC",205
# "TURBO TRANS CORP",197
# "TURETSKY,MIKHAIL",108
# "TURGUT,AHMET,A",83
# "TUSHAR TRANSIT LLC",108
# "TUZCUOGLU,HASAN,B",105
# "TW CHAUDHRY, LLC",26
# "TWENTY-ONE HACKING CORP",222
# "TWIN JET HACKING CORP",199
# "TWINEY LLC",59
# "TWINKIE TAXI LLC",89
# "TWINKLE CAB CORP",203
# "TWINS TRANSIT INC",166
# "TWO A SIXTY FIVE INC",111
# "TWO ABOVE HACKING CORP",186
# "TWO ALEX TAXI INC.",208
# "TWO BELOW  HACKING CORP",222
# "TWO CAB CORP.",205
# "TWO DEGREES HACKING CORP",235
# "TWO F75 CAB INC",117
# "TWO FILOI TAXI INC.",210
# "TWO HUMP TAXI LLC",100
# "TWO JOES HACKING CORP",220
# "TWO MULTANI BROTHERS LLC",34
# "TWO SISTERS TAXI LLC",101
# "TWO SONS TAXI LLC",100
# "TWO THUMBS CAB LLC",4
# "TWO-EIGHTY INC",192
# "TYME CAB CORP",223
# "TYPHOON HACKING CORP",207
# "TYRANT HACKING CORP",216
# "TYSON CAB LLC",2
# "TYTL CAB CORP",64
# "TYZAC TAXI CORP.",106
# "TZAR CAB CO., INC.",108
# "TZEDAKEH TRANSIT LLC",231
# "TZORZIS, SPYRIDON,N",30
# "TZT TANJIA LLC",93
# "U.T.C. TRANSPORTATION CORP.",213
# "UA CHAUDHRY, LLC",89
# "UDACHA TAXI INC",184
# "UDDIN TAXI CORP",193
# "UDDIN, SHAHAB",105
# "UDDIN,BOSIR",105
# "UDDIN,GOLAM,M",100
# "UDDIN,JOYNAL",115
# "UDDIN,KAMAL",88
# "UDDIN,MAHBUB & HAQUE,NAZIMUL",110
# "UDDIN,MOHAMED,N",98
# "UDDIN,MOHAMMAD,S",105
# "UDDIN,MOHAMMED,N",95
# "UGARTE,NELLY",107
# "UGAS, MARIA LUISA",92
# "UKRAINE SERVICE CO INC",246
# "ULAS CAB CORP.",80
# "ULCENA, ANTIOCHE",88
# "ULLAH,SHEIKH,M",113
# "ULLAH,URFAN & CHOUDHARY,FAISAL",104
# "ULNA CAB CORP",212
# "ULSTER TRANSPORTATION CORP",191
# "ULTIMATE TRANSIT LLC",159
# "ULU CAB LLC",9
# "ULUDAG, SENIHA",26
# "ULYSSE, EWHIDBY & DESSALINES, IDLAIRE",41
# "ULYSSE, FLAUBERT & CIENETTE",102
# "ULYSSE, FRANCOIS",40
# "ULYSSE, GAUTHIER",68
# "ULYSSE, JOCELYN",86
# "ULYSSE,EDRICE",76
# "UMBRELLA CAB CORP",105
# "UNICORN CAB CORP.",77
# "UNIT CAB CORP",25
# "UNIT CAB CORP.",47
# "UNITED AGAMI TRANSIT INC.",223
# "UNITED FOUR STARS LLC",94
# "UNITED MENSAH CORP",190
# "UNIVERSAL AGAMI TRANSIT INC.",211
# "UNIVERSE TAXI INC",222
# "UPPAL,MANGAL,SINGH&KALER,MONOHAR",122
# "UPPAL,RAJINDER,SINGH",103
# "UPSILON CAB CORP",218
# "UPTOWN TAXI LLC",88
# "UPURS, LLC",157
# "UQUILLAS, CARLOS",91
# "URBAN GREEN CAR LLC",32
# "URBANA CAB CORP",214
# "URENA,MAXIMO",68
# "URISOV,WILLIAM",73
# "URN CAB CORP",219
# "URUGUAY CAB CORP",220
# "USA CAB LLC",50
# "USA KHALSA LLC",50
# "USEFUL TAXI LLC",113
# "USHMAN,BORIS",82
# "USMAN,ZAHID",94
# "UTC TRANSPORTATION CORP",177
# "UTC TRANSPORTATION CORP.",99
# "UTOE CAB LLC",8
# "UTOPIA TAXI INC.",234
# "UTRO TAXI INC",108
# "UTULATE TRANSIT INC.",172
# "UVAYDOV, IMMANUIL",43
# "UVAYDOV,MIKHAIL",121
# "UVAYDOV,YURIY",79
# "UZZAL CAB CORP",211
# "V & A CAB CORP",197
# "V V CAB CORP",204
# "V&F CAB CORP",216
# "V&T EXPRESS CAB CORP.",95
# "V. B. TAXI CORP.",187
# "V.E.A. RIDERS CORP",101
# "V.M. CAB CORP",212
# "V.W. CAB CORP.",217
# "V12 BENZ SERVICE CO., INC.",202
# "VACATION TRANSIT INC.",214
# "VAHEGURU JIDI BAKHSHISH TAXI CORP.",106
# "VAINER, ELIZAVETA",117
# "VAISMAN, LEONID",88
# "VAKNIN, JACK",106
# "VAL, RENE",79
# "VALBRUNE,FREYCINET",1
# "VALCIN, JOSEPH V.",107
# "VALCIN, PAULEMA",104
# "VALCIN, SAMUEL",110
# "VALENTI, ROSE",111
# "VALERICE,MIMOSE",53
# "VALERY TRANS INC",225
# "VALERY, CLAUDE A.",90
# "VALET,EDNER",99
# "VALMA TRANS CORP.",212
# "VALME, MARIE JOSE",99
# "VANCOL,YVES",102
# "VANDNA TRANSPORT INC",90
# "VANDNA TRANSPORT, INC",77
# "VANGELATOS, MARY & SOTIRIOS",108
# "VANGELATOS,GERASIMOS",95
# "VANUA CAB CORP",208
# "VARAITCH,RESHAM",114
# "VARDANIAN, HRACHIA",100
# "VARDHAN,RAJ",89
# "VARGAS, MARCELINO",93
# "VARGAS,LUIS,A",106
# "VARGHESE, MATHAI",88
# "VARIA TRANSPORT INC.",239
# "VARINIA TRANSIT INC",212
# "VARNISHKES TRANSIT LLC",129
# "VARRES, INC",230
# "VAS TAXI INC",225
# "VASHIST,SETNIWAS & VASHIST,RAM,N",113
# "VASILIKI TAXI INC.",56
# "VASILIS TAXI INC.",17
# "VASQUEZ,ALEJANDRO",101
# "VASSALLO, LEONARD T.",46
# "VATOPEDI LLC",56
# "VAVAL TAXI CORP",146
# "VAVASIS, KONSTANTINOS",118
# "VAX CONSULTANTS",12
# "VAYNSHTOK,ILYA",113
# "VAYSBERG,MARAT",107
# "VAYSMAN, MARAT",4
# "VAZQUEZ,LUIS,RICARDO",62
# "VBA TAXI CORP.",90
# "VDELES LLC",101
# "VDK TRANSPORTATION LLC",45
# "VEDRINE,ARCHANGE",101
# "VEGAS CAB CORP",186
# "VEHEGURU LLC",104
# "VEKSLER,MENDEL,M",104
# "VEL CAB CORP",371
# "VELA,ABEL,N",96
# "VELAORAS,SPYRIDON",101
# "VELASQUEZ, EDGAR",107
# "VELASQUEZ,GUSTAVO",102
# "VELAZQUEZ, LOUIS",81
# "VELIZ,LIBERT.O",107
# "VEM TRANS CORP",178
# "VENA TAXI INC",114
# "VENORD, JEAN",48
# "VENORD, SEIDE",107
# "VENORD,JEAN M.",113
# "VENTKATE INC.",233
# "VENTURE CAB CORP.",212
# "VENUS MOTOR LTD",214
# "VERESMORTEAN, IOAN",64
# "VERGARA, JESUS",104
# "VERITY TAXI INC",146
# "VERMA, NAVIN",75
# "VERMA,RAJ,KUMAR",112
# "VERMOUTH TAXI INC",207
# "VERO H LLC",111
# "VESTRY TAXI LLC",231
# "VETA TRANS CORP.",112
# "VETERANS STATION CORP.",220
# "VIAGGIO TAXI INC",342
# "VIAM TRANSPORTATION CORP",47
# "VIARD, JEAN C.",105
# "VICE TRANSIT INC",229
# "VICHY CAB CORP.",214
# "VICMARIE HACKING CORP.",234
# "VICS TAXI INC",174
# "VICTOR JAN TAXI INC",230
# "VICTOR, DANIEL",91
# "VICTORIA CAB CORP",242
# "VICTORIA FUNDING HOLDING LLC",57
# "VICTORIA FUNDING HOLDINGS LLC",400
# "VICTORIA TRANSIT INC.",45
# "VIEUX, VANES",111
# "VIEW CAB CORP.",42
# "VIG,SANJIV",85
# "VIGILANCE,MAURICE,F",66
# "VIIXI TAXI INC",151
# "VIJAY & SHARAN CAB CORP.",151
# "VIJAY TRANS CORP",229
# "VILAIN,FRANTZ",103
# "VILBON,DUCARMEL",88
# "VILCEUS, MARCELLUS",133
# "VINAYEK,SANDEEP",106
# "VINCE NY LLC",109
# "VINCENT, RENEL/LOUISSANT,EDDY",98
# "VINCENZO & ELISA LLC",92
# "VINLO CAB CORP",223
# "VINNY LLC",30
# "VIOLET TRANSIT INC",221
# "VIOLIN CAB CORP",243
# "VIP TAXI CORP",425
# "VIPER CAB CORP.",80
# "VIRGILI, PIETRO",95
# "VIRGIN TAXI INC",149
# "VIRK & NIDHAN LLC",53
# "VIRK,BALVINDER,SINGH",122
# "VISTOSO, FRANCISCO",51
# "VITAL CAB CORP",206
# "VITAL, ALPHONSE",106
# "VITOMSKY, EFIM",101
# "VITTORIA TAXI CORP.",214
# "VIVALDI TRANSIT INC",220
# "VIXAMA,LUCIEN",20
# "VIXAMAR,MAURICE,S",102
# "VIXAN CAB CORP",211
# "VIZANIARIS, NIKI",107
# "VIZIOLI, VINCENT",78
# "VIZUETA, ALEXANDER",44
# "VJOSA CAB CORP",192
# "VLACHOS,ELEFTHERIOS",124
# "VLACHOS,STAVROS",114
# "VLADFIL TAXI INC",203
# "VLAHAKIS, ADAM",42
# "VLANAT TAXI CORP",202
# "VO,DAN,THE",115
# "VOBLA TAXI INC",197
# "VODKA TAXI LLC.",71
# "VODOFF, VLAD",63
# "VODOVOZ, USHER",104
# "VOGUE CAB CORP",200
# "VOILA TAXI INC",157
# "VOIN TAXI INC",191
# "VOLARE CAB CORP",224
# "VOLCANIC HACKING CORP",167
# "VOLCY, ZACHEE",108
# "VOLCY,GEORGES,F",103
# "VOLKOV, PESACH",82
# "VOLLEY BALL TAXI LLC",108
# "VOLONAKIS, GEORGE",63
# "VOLOS TAXI INC",110
# "VOLTAIRE, JOSEPH & MARIE",108
# "VOLTUS, CHARLES",95
# "VOLVO CAB CORP",205
# "VORTEX HACKING CORP",179
# "VOSIEM HACKING CORP",216
# "VOUNO, INC.",258
# "VOURVOUROU TAXI LLC",4
# "VOURVOURROU TAXI LLC",1
# "VOVCHIK TAXI, INC.",223
# "VOZDUX TAXI INC.",58
# "VP WILLIAMS TRANS LLC",100
# "VROUKOUNTA TRANS INC",213
# "VSOP TAXI INC",82
# "VTRX EB LLC",201
# "VULIKHSHER, MICHAEL",107
# "VULLIS CORP.",194
# "VULTURE CAB CORP",206
# "VURAL, AHMET",131
# "W BREIT TAXI INC",204
# "W BUY TRANS CORP",336
# "W LIN CAB CORP",205
# "W LOL TRANS CORP",216
# "W MIT  TRANS CORP",232
# "W RYK TRANS CORP",313
# "W SAM TRANS CORP",310
# "W SAR TRANS CORP",203
# "W VIL TRANS CORP",201
# "W.B.L.S. TAXI INC",225
# "W.G.H.H. TAXI INC",239
# "WAEL D.E.TAXI CORP.",94
# "WAGON SERVICE CORP",211
# "WAHEE GURU TRANS LLC",90
# "WAHEED, ABDUL",99
# "WAHEED,MOHAMMAD",52
# "WAHEHE LIMITED",219
# "WAHID, MOHAMED M.",104
# "WAHO TAXI INC.",116
# "WAINS CAB CORP",214
# "WALIA, AVTAR SINGH",100
# "WALIA,PRABHJOT,K",112
# "WALIA,SURINDERJIT,S",100
# "WALK CAB CORP",211
# "WALKER SERVICE CORP",202
# "WALL TAXI INC",218
# "WALOIL INC",218
# "WALTER, ROGER",102
# "WALUNG GOMBA TAXI LLC",106
# "WAN S. LAU_& MARY Q. LAU",97
# "WANG, WILLIAM & SUET-HING",99
# "WANG,JACK",97
# "WARAICH,GURDEV,S",105
# "WARD TAXI INC",312
# "WARD, WILLIAM G.",101
# "WARE TAXI INC",225
# "WAREHAM CAB CORP",238
# "WARRAICH CAB CORP.",86
# "WASP TAXI LLC",69
# "WASZCZUK,WALDEMAR",105
# "WATER TAXI INC",214
# "WATERSPOUT HACKING CORP",227
# "WAVE TAXI INC",336
# "WAY CAB LLC",48
# "WAYABO TAXI INC.",89
# "WAYLON TRANSIT LLC",145
# "WAZERI, ANI",119
# "WAZIRI,KHALILULLAH",105
# "WEBER,EDWARD",100
# "WEE TRANSPORT CORP.",323
# "WEI CHENG CHANG CORP.",139
# "WEINER, LOUIS",107
# "WEISS, ARTHUR",98
# "WELLCOME SERVICE CORP",199
# "WEN,CHI,KAI",87
# "WENGER, RICHARD S.",97
# "WEON SEOG CHOI",97
# "WERT CAB CORP",193
# "WERTENTEIL, ISRAEL",80
# "WEST 48 ST TAXI INC",214
# "WEST CAB CORP",194
# "WEST EXPRESS CAB CORP",195
# "WEST FIFTH STREET SERVICE CO., INC.",171
# "WEST SERVICE CORP",207
# "WEST,GEORGE,J",72
# "WEST,GERALD",113
# "WESTEN, LARRY J.",93
# "WESTVIEW TAXI LLC",214
# "WHAT'S NEXT TAXI INC",200
# "WHATS YELLOW LLC",205
# "WHEEL TRANS CORP.",173
# "WHIMBREL CAB CORP",200
# "WHIPPET TRANS CORP",204
# "WHISPERS TAXI INC.",80
# "WHITE EXPRESS CAB CORP",226
# "WHITE PIDGEON EXPRESS CAB CORP",225
# "WHITE, JOE L.",81
# "WHITEDOVE CAB CORP",207
# "WHITEOUT HACKING CORP",98
# "WHITEWIDOW HACKING CORP",159
# "WHYSE TAXI INC",225
# "WILANSKY, SHERWIN",103
# "WILBURY TAXI LLC",321
# "WILD FLOWER CAB CORP",201
# "WILD SHAUN HACKING CORP",176
# "WILDER,TEEJAY",96
# "WILDWOOD HACKING CORP",204
# "WILFRED,ROHAN",112
# "WILK CAB CORP",138
# "WILK, TEDDY",97
# "WILLIAM, GERARD",98
# "WILLIAM,FRANTZ",81
# "WILLIAMS, PETER",122
# "WILLIAMS,MONICA",16
# "WILLIAMSBURG PLAZA TAXI INC",553
# "WILLIAMSBURG TAXI CO INC",344
# "WILLIE TRANSIT LLC",157
# "WILLY AND SONS INC.",107
# "WILSON, EDDIE",88
# "WILSON, RADIX",61
# "WIMA TAXI CORP",225
# "WIN WIN MAW INC.",122
# "WIND CAB CORP.",155
# "WIND HACKING CORP",200
# "WIND JAMMER LLC",9
# "WINDER,TAL",75
# "WING FAT TAXI INC",212
# "WING N. MOY",104
# "WING SHING INC.",94
# "WINK CAB CORP",205
# "WISDOM CAB CORP.",208
# "WISS & BROTHERS CORP.",104
# "WISTERIA TAXI LLC",209
# "WITT CAB CORP",207
# "WLODARCZYK, MAREK",80
# "WOJTKOWSKI, EUGENE",99
# "WOLCZYNSKI,MICHAL,J.",101
# "WOLF CAB CORP.",76
# "WOLFSON, MILTON",88
# "WOLVERINE TAXI LLC",68
# "WONDAL, JOHN",34
# "WONG, AH LIN",119
# "WONG, DUG,F",93
# "WONG, KAM TAT",102
# "WONG, SUI, YEN",108
# "WONG,CHEK,YEE",106
# "WONG,CHUNG,HAU",107
# "WONG,JAMES",107
# "WONG,KIN CHUEN",103
# "WONG,KING,F",94
# "WONG,MAN,S.",106
# "WONG,MICHAEL",86
# "WONG,NELSON",99
# "WONG,OI,CHUEN",115
# "WONG,SING,K",114
# "WONG,STEVEN",108
# "WONG,TSUN,YIN",102
# "WONG,WAI,S",104
# "WOOFMAN HACKING CORP.",199
# "WORK CAB CORP.",221
# "WORKING GIRL TAXI INC",233
# "WORLD TAXI LLC",91
# "WORTH TRANS INC",311
# "WORTHINGTON TAXI CORP",173
# "WRESTLER TAXI LLC",88
# "WRIGHT, PAUL",112
# "WRONSKI, GRZEGORZ",90
# "WU, SIGMOND",88
# "WU, VICTOR",116
# "WU,DAVID PEIJI",119
# "XARA, INC",207
# "XEKOLIARES LLC",197
# "XENO CAB LLC",131
# "XENOULA LLC",111
# "XERUS CAB CORP.",66
# "XIFIAS TRANS INC",552
# "XIOS TAXI CORP",216
# "XO TAXI INC",84
# "XORAN CAB CORP",148
# "XOROFILAKAS,LLC",120
# "XOULAKIA LLC",40
# "XU,GUO,PING",97
# "Y & IRMA HACKING CORP",214
# "Y & M TAXI INC",216
# "Y & Y TAXI INC",216
# "Y BOBBY TAXI INC",191
# "Y CHANA TAXI INC",214
# "Y DADDY TAXI INC",217
# "Y MATI TAXI INC.",179
# "Y MEIR TAXI INC",215
# "Y MICHAL TAXI INC",206
# "Y MOMMY TAXI INC",203
# "Y NINA TAXI INC",221
# "Y NOT TAXI INC",207
# "Y SHIRI TAXI INC",210
# "Y T R TAXI INC",243
# "Y TALLI TAXI INC",223
# "Y TOMMY TAXI INC",228
# "Y-BILLY BOYS TAXI INC",217
# "Y. BIG Z TAXI INC.",328
# "Y. BILLY TAXI INC.",216
# "Y. DAREK TAXI INC.",298
# "Y. JOEY TAXI INC",210
# "Y. MIKE TAXI INC",242
# "Y. RON TAXI INC.",201
# "Y.BABY TAXI INC",242
# "Y.K.L. TAXI INC",225
# "Y.Z.N. TAXI INC.",193
# "YAAM CAB CORP.",204
# "YAASEEN LLC",48
# "YAD CAB CORP",212
# "YADGAROV, DANIEL",93
# "YAEL TAXI CORP",130
# "YAFFA HACKING CORP",51
# "YAFIT CAB CORP.",331
# "YAGODKA TAXI INC.",222
# "YAGUDAEV,YURI",101
# "YAK TAXI INC",213
# "YAKUBOV, ALBERT & EDUARD",23
# "YAKUBOV, BORIS",124
# "YAKUBOV,IRMA",119
# "YAKUBOV,SULEYMAN",104
# "YAMPOLSKIY, SHAYA",81
# "YAN,PAK,CHONG",102
# "YANG, KWONG WAI",43
# "YANICK GG, LLC",113
# "YANIV EXPRESS CAB CORP",188
# "YANKEEKAP CO. INC.",107
# "YANKL TRANSIT INC",207
# "YANOVSKY,ALEXANDER",101
# "YANUSH TAXI INC.",207
# "YAP, MICHAEL",116
# "YAPI, JEAN, MICHEL",59
# "YAQUBI,ABDULLAH",77
# "YAR,AHMAD",119
# "YAR,MUDDASSAR,I",30
# "YARO TRAVEL INC.",37
# "YARON, BEHIRA",97
# "YARON,DORON",92
# "YASAYEV,MIKHAIL",101
# "YASHPREET TAXI CORP.",104
# "YASIA TAXI CORP",208
# "YAW A. NUAMAH",93
# "YAYAS CAB CORP",161
# "YAZICI & OZSU SERVICE CORP.",167
# "YEBYAN LLC",103
# "YEDIDA TAXI INC",226
# "YEE,CHIAO-HUNG & YEE,MEI,HSIANG",98
# "YEE,LICIA",86
# "YEFIM & MIKHAIL CAB CORP",110
# "YEGAL EXPRESS CAB CORP",204
# "YEH,DENNIS,J",110
# "YEHIA LLC",122
# "YELLOW BIRD OF NY LLC",3
# "YELLOW CARAVAN TAXI LLC",218
# "YELLOW CARRIAGE TAXI LLC",214
# "YELLOW CITY LLC",222
# "YELLOW DEVIL TAXI LLC",226
# "YELLOW DIAMOND OF NY LLC",2
# "YELLOW DIAMOND TAXI LLC",179
# "YELLOW DREAMS CAB CORP.",181
# "YELLOW EXPRESS CAB CORP",203
# "YELLOW JITNEY CORP.",101
# "YELLOW LINE TAXI INC.",162
# "YELLOW RAVEN CAB CORP",220
# "YELLOW ROCKET TAXI LLC",231
# "YELLOW STARS TRANSIT,LLC",75
# "YES DEAR EXPRESS CAB CORP",220
# "YEUNG,WING,FAI",108
# "YEVSIF CAB CORP",201
# "YIM, PAUL,C.",86
# "YIORGOS LLC",213
# "YIOTA TAXI INC",203
# "YIU MAN YU AKA JOHNNY YU",29
# "YMAS CAB CORP.",32
# "YME TRANSIT INC.",212
# "YO FOXY TAXI INC.",114
# "YOETS, SHLOMI",108
# "YOGI TRANS CORP",245
# "YOHA TRANSIT, LLC",185
# "YOHAY,PAUL,J",23
# "YOKUM TRANSIT LLC",174
# "YONIK & ALEX TAXI INC",211
# "YONUIR INC.",208
# "YOON, DAE JIN",105
# "YORAM SERVICE CORP",221
# "YORK TAXI INC.",152
# "YOSHIHARA, AKIO",93
# "YOSI TRANSIT INC.",206
# "YOUNG CAB CORP",102
# "YOUNG, ART C.",76
# "YOUNG, SAMUEL",125
# "YOUNG, TOMMY",90
# "YOUNG,MARISA,A",12
# "YOUNTEN LLC",99
# "YOUR EXPRESS CAB CORP",200
# "YOUSAF,BILAL",108
# "YOUSSEF TAXI CORP.",222
# "YOUSSEF,IBRAHIM,M",111
# "YOYO CAB CORP",433
# "YSHUA, MAIR",80
# "YU,HAI,WEI",109
# "YU,MICHAEL,Y",104
# "YUAN,SHAO,MING",28
# "YUCETURK, RECEP",102
# "YUEH,TZONG,YIH",104
# "YUKHANANOV, GABRIEL",108
# "YUKSEL,ATILLA",94
# "YUN,CHARLIE",101
# "YUNO TAXI INC.",102
# "YUSHUVAYEV,ROZA",116
# "YUSUPOV, ISAK",95
# "YUSUPOV,GAVRIEL",104
# "YUSUPOV,IGOR,B",107
# "YUVRAJ TAXI CORP.",89
# "YVEBO LLC",91
# "Z & E TAXI INC",212
# "Z & S TRAVEL LLC",29
# "Z P A 786 CORP.",2
# "Z-N TAXI INC",215
# "Z. H. I. TAXI INC.",184
# "ZABROXO TAXI INC.",42
# "ZACH TRANS CORP.",209
# "ZACHARY CAB CORP.",113
# "ZACK TAXI INC.",87
# "ZADI, ABRAHAM G.",108
# "ZADRAN, MOMIN K.",96
# "ZADRAN, RAHMATULLAH",87
# "ZADRAN, ZAHEER",103
# "ZAEL TAXI LLC",116
# "ZAFAR CHEEMA TAXI CORP.",93
# "ZAFAR,TAHSEEN & ZAFAR,USMAN",110
# "ZAHAL TAXI CORP",162
# "ZAHARO CAB CORP.",150
# "ZAHAV TAXI LLC",222
# "ZAHID,AHMAD,ZIA",113
# "ZAIDMAN,NATAN",98
# "ZAINAL AND SAYEDUL CORP.",118
# "ZAINI, MOHAMMAD",104
# "ZAINTZ, TIKVA",109
# "ZAINTZ,MURRAY",112
# "ZAKARIA TRANS CORP.",4
# "ZAKHARYAYEV, MARINA",82
# "ZAKHARYAYOV,RASHBIL",101
# "ZAKINTOS & PLATANOS CAB CORP",188
# "ZAMA, CAMILLE",103
# "ZAMALEK CAB CORP.",31
# "ZAMAN, MOHAMMADULLAH",138
# "ZAMAN, SAMIULLAH",25
# "ZAMAN,MOHAMMED,I",101
# "ZAMAN,NURUZ",60
# "ZAMPALA TAXI LLC",80
# "ZANE CAB CORP",225
# "ZANETTAS TAXI LLC",224
# "ZANTE CAB CORP",202
# "ZAPT TAXI LLC",21
# "ZARAN CORP.",106
# "ZARATE CAB CORP.",105
# "ZARATE,JOSE",99
# "ZARETSKIY, OLEG",99
# "ZARMAKOUPIS,KONSTANTINO,I. & DIMINO,JOSEPH",126
# "ZARO CAB CORP",197
# "ZASLAV,VITALY",58
# "ZAVADSKY,ALEXANDER",132
# "ZAVADSKY,YULY",126
# "ZAVARS TAXI INC.",62
# "ZAVLANOV,EDUARD,I",115
# "ZAZA TAXI LLC",205
# "ZAZOMUJ TAXI CORP.",99
# "ZDS TAXI INC.",127
# "ZEAL SERVICE CORP.",226
# "ZEBRA CAB CORP.",85
# "ZEE, ROBERT",105
# "ZEE,SING,C",48
# "ZEESHAN,MUHAMMAD",99
# "ZEKE SERVICE CORP",213
# "ZELINGER,IRWIN,I",16
# "ZEMA CAB CORP",200
# "ZEN TAXI LLC",114
# "ZENA & SOL TAXI INC",189
# "ZEPHIR,DIEULIUS",44
# "ZESSIMOPOULOS, COSTAS",107
# "ZESSIMOPOULOS, EUDOXIA",111
# "ZEST CAB CORP",216
# "ZETA TRANS CORP",219
# "ZEUS TRANSPORT INC",221
# "ZFAT TIBERIAS JERUSALEM CAB CORP",172
# "ZHU,BISHENG",108
# "ZIARNO, ZVI S.",122
# "ZIELINSKI,LESLAW",107
# "ZIFLIO LLC",81
# "ZILIARA LLC",251
# "ZINC ONE SERVICE CORP",91
# "ZINC TAXI INC",203
# "ZINDEL EXPRESS CAB CORP",199
# "ZION TAXI INC",226
# "ZION TRANSIT INC.",199
# "ZION, EDMOND",84
# "ZIP TRANSIT INC",186
# "ZIROPOULOS,DIMITRIOS",101
# "ZISIMOPOULOS, THEODOROS",95
# "ZISIMOPOULOS,ATHENA",99
# "ZITI CAB LLC",113
# "ZIVA CAB CORP",209
# "ZL TRANSIT INC.",226
# "ZLOTCHENKO, ADOLF",92
# "ZLUCHKA TAXI INC",182
# "ZMZM TAXI CORP.",83
# "ZODIAC TAXI INC",190
# "ZOE CAB CORP.",202
# "ZOHAR TRANSIT INC",103
# "ZOLTAN TRANS LLC",103
# "ZOQUE TAXI INC",210
# "ZOR,MEHMET",75
# "ZORBAS,KONSTANTINOS,POLIKARPOS",95
# "ZORIA BROTHER CORP.",117
# "ZORM TRANSIT CORP",145
# "ZORRO TAXI INC",202
# "ZOYA TAXI CAB INC",203
# "ZOZO TAXI LLC",70
# "ZR TAXI INC.",30
# "ZUKIN,ALEXANDER",90
# "ZULIE TAXI INC",200
# "ZUMBA,LUIS",110
# "ZUNINKEH TRANSIT LLC",150
# "ZUPIS TAXI INC",209
# "ZUS TRADING INC",93
# "ZUTNAQ LLC",38
# "ZUTO,GENE",52
# "ZVULOON EXPRESS CAB CORP.",193
# "ZYCH, MARIUSZ",92
# Removing temp directory /tmp/mymrjob1.e11924480.20210425.075336.621293...

# %% [markdown]
# Running a Hadoop job

# %%
! HADOOP_HOME=/opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/ python mymrjob1.py -r hadoop hdfs:///home/adbs21/shared/medallion-vehicles.csv > output.csv
# Out:
# No configs found; falling back on auto-configuration
# No configs specified for hadoop runner
# Looking for hadoop binary in /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/bin...
# Looking for hadoop binary in $PATH...
# Found hadoop binary: /usr/bin/hadoop
# Using Hadoop version 3.0.0
# Looking for Hadoop streaming jar in /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/...
# Found Hadoop streaming jar: /opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/hadoop-streaming.jar
# Creating temp directory /tmp/mymrjob1.e11924480.20210425.075632.005884
# Copying local files to hdfs:///user/e11924480/tmp/mrjob/mymrjob1.e11924480.20210425.075632.005884/files/...
# Running step 1 of 1...
#   WARNING: Use "yarn jar" to launch YARN applications.
#   Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#   packageJobJar: [] [/opt/cloudera/parcels/CDH-6.3.2-1.cdh6.3.2.p0.1605554/jars/hadoop-streaming-3.0.0-cdh6.3.2.jar] /tmp/streamjob2116069636177104468.jar tmpDir=null
#   Connecting to ResourceManager at c100.local/10.7.0.100:8032
#   Connecting to ResourceManager at c100.local/10.7.0.100:8032
#   Disabling Erasure Coding for path: /user/e11924480/.staging/job_1596895008206_20293
#   Total input files to process : 1
#   number of splits:17
#   yarn.resourcemanager.system-metrics-publisher.enabled is deprecated. Instead, use yarn.system-metrics-publisher.enabled
#   Submitting tokens for job: job_1596895008206_20293
#   Executing with tokens: []
#   resource-types.xml not found
#   Unable to find 'resource-types.xml'.
#   Submitted application application_1596895008206_20293
#   The url to track the job: http://c100.local:8088/proxy/application_1596895008206_20293/
#   Running job: job_1596895008206_20293
#   Job job_1596895008206_20293 running in uber mode : false
#    map 0% reduce 0%
#    map 32% reduce 0%
#    map 39% reduce 0%
#    map 42% reduce 0%
#    map 45% reduce 0%
#    map 51% reduce 0%
#    map 55% reduce 0%
#    map 66% reduce 0%
#    map 88% reduce 0%
#    map 98% reduce 0%
#    map 100% reduce 0%
#    map 100% reduce 70%
#    map 100% reduce 73%
#    map 100% reduce 76%
#    map 100% reduce 79%
#    map 100% reduce 82%
#    map 100% reduce 85%
#    map 100% reduce 88%
#    map 100% reduce 91%
#    map 100% reduce 94%
#    map 100% reduce 97%
#    map 100% reduce 100%
#   Job job_1596895008206_20293 completed successfully
#   Output directory: hdfs:///user/e11924480/tmp/mrjob/mymrjob1.e11924480.20210425.075632.005884/output
# Counters: 55
# 	File Input Format Counters
# 		Bytes Read=2278886238
# 	File Output Format Counters
# 		Bytes Written=258967
# 	File System Counters
# 		FILE: Number of bytes read=15231710
# 		FILE: Number of bytes written=36985666
# 		FILE: Number of large read operations=0
# 		FILE: Number of read operations=0
# 		FILE: Number of write operations=0
# 		HDFS: Number of bytes read=2278888159
# 		HDFS: Number of bytes read erasure-coded=0
# 		HDFS: Number of bytes written=258967
# 		HDFS: Number of large read operations=0
# 		HDFS: Number of read operations=56
# 		HDFS: Number of write operations=2
# 	Job Counters
# 		Data-local map tasks=4
# 		Launched map tasks=17
# 		Launched reduce tasks=1
# 		Rack-local map tasks=13
# 		Total megabyte-milliseconds taken by all map tasks=2535285760
# 		Total megabyte-milliseconds taken by all reduce tasks=398320640
# 		Total time spent by all map tasks (ms)=495173
# 		Total time spent by all maps in occupied slots (ms)=25748996
# 		Total time spent by all reduce tasks (ms)=77797
# 		Total time spent by all reduces in occupied slots (ms)=4045444
# 		Total vcore-milliseconds taken by all map tasks=495173
# 		Total vcore-milliseconds taken by all reduce tasks=77797
# 	Map-Reduce Framework
# 		CPU time spent (ms)=569930
# 		Combine input records=0
# 		Combine output records=0
# 		Failed Shuffles=0
# 		GC time elapsed (ms)=49404
# 		Input split bytes=1921
# 		Map input records=13518773
# 		Map output bytes=289954224
# 		Map output materialized bytes=17665178
# 		Map output records=13518772
# 		Merged Map outputs=17
# 		Peak Map Physical memory (bytes)=2063704064
# 		Peak Map Virtual memory (bytes)=6526660608
# 		Peak Reduce Physical memory (bytes)=743415808
# 		Peak Reduce Virtual memory (bytes)=6563909632
# 		Physical memory (bytes) snapshot=23147810816
# 		Reduce input groups=10296
# 		Reduce input records=13518772
# 		Reduce output records=10296
# 		Reduce shuffle bytes=17665178
# 		Shuffled Maps =17
# 		Spilled Records=27037544
# 		Total committed heap usage (bytes)=53749481472
# 		Virtual memory (bytes) snapshot=113302577152
# 	Shuffle Errors
# 		BAD_ID=0
# 		CONNECTION=0
# 		IO_ERROR=0
# 		WRONG_LENGTH=0
# 		WRONG_MAP=0
# 		WRONG_REDUCE=0
# job output is in hdfs:///user/e11924480/tmp/mrjob/mymrjob1.e11924480.20210425.075632.005884/output
# Streaming final output from hdfs:///user/e11924480/tmp/mrjob/mymrjob1.e11924480.20210425.075632.005884/output...
# STDERR: 21/04/25 09:58:52 WARN util.NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Removing HDFS temp directory hdfs:///user/e11924480/tmp/mrjob/mymrjob1.e11924480.20210425.075632.005884...
# Removing temp directory /tmp/mymrjob1.e11924480.20210425.075632.005884...

# %% [markdown]
# ---
#
# - ### **b) Write a MapReduce job with both datasets as input and following output:**
# For each company with a medallion vehicle, show the number of parking violations they received
# for these vehicles. Make sure to have the following format in your final output:
#             name,count_violations

# %%
# %%file mymrjob2.py
# This will create a local file to run your MapReduce program  

from mrjob.job import MRJob
from mrjob.step import MRStep
from mrjob.util import log_to_stream, log_to_null
from mr3px.csvprotocol import CsvProtocol
import csv 
import logging

# 
#  Below is the skeleton for a MapReduce program in mrjob.
#  Write your own solution here. Be sure that it actually runs successfully.

class MyMRJob2(MRJob):
    
 log = logging.getLogger(__name__)
# 
#  Below is the skeleton for a MapReduce program in mrjob.
#  Write your own solution here. Be sure that it actually runs successfully.
class MyMRJob2(MRJob):
    
    
    OUTPUT_PROTOCOL = CsvProtocol  # write output as CSV
    
    def set_up_logging(cls, quiet=False, verbose=False, stream=None):  
        log_to_stream(name='mrjob', debug=verbose, stream=stream)
        log_to_stream(name='__main__', debug=verbose, stream=stream)

#   Feel free to rename the functions
    def mapper_mrjob2(self, _, line):
        #TODO
        
# use of a combiner is optional. It may speed up your job. Be sure that using the combiner preserves the correctness. 
#     def combiner_mrjob2(self,key,valuelist):
        #TODO
        
    def reducer_mrjob2(self,key,valuelist):
         #TODO

    def steps(self):
        first_step = MRStep(
            mapper=self.mapper_mrjob2, 
#             combiner=self.combiner_mrjob2, 
            reducer=self.reducer_mrjob2
        )
        # just generate more steps to run a multi-step MR job
        
        return [ first_step ]

if __name__ == '__main__':
    MyMRJob2.run()
# Out:
# Overwriting mymrjob2.py

# %% [markdown]
# Running a local MRjob

# %%
! python mymrjob2.py  /home/adbs21/shared/medallion-vehicles-short.csv /home/adbs21/shared/parking-violations-short.csv

# %% [markdown]
# Running a Hadoop job

# %%
! HADOOP_HOME=/opt/cloudera/parcels/CDH/lib/hadoop-mapreduce/ python mymrjob2.py -r hadoop hdfs:///home/adbs21/shared/medallion-vehicles.csv hdfs:///home/adbs21/shared/parking-violations.csv > output2.csv

# %% [markdown]
# ---
#
# - ### **c) Once your jobs have run successfully on the cluster, use the provided commands in the notebook to look up the counters of your Mapreduce job(s).**
# Alternatively, you can also read the counters from the output cells above, after a job has succesfully run on the cluster.
# Use the counters to determine for each job what the replication rate and the communication cost was, as well as the input and output size. For this you will need to determine the job ids. These are shown in the output when running a job.
#
# **Note:** _Be sure to replace the dummy job ID below with the real one you get after running it on the cluster!_
#
# **Info on the relevant counters**:
#
# MAP_INPUT_RECORDS  .... _indicates the sum of all of input records  received by mappers_
# MAP_OUTPUT_RECORDS  .... _indicates the sum of all output records emitted by mappers_
# MAP_OUTPUT_BYTES  .... _indicates the total size in bytes of the records output by all the mappers_
# BYTES_READ  .... _indicates the number of bytes read by the MapReduce Job from the filesystem_
# BYTES_WRITTEN  .... _indicates the number of bytes written by the MapReduce Job to the filesystem_
#
# If you want to use more counters, you can find a list in the documentation:
# https://hadoop.apache.org/docs/r2.10.1/api/org/apache/hadoop/mapreduce/TaskCounter.html
# https://hadoop.apache.org/docs/r2.10.1/api/org/apache/hadoop/mapreduce/lib/input/FileInputFormatCounter.html
# https://hadoop.apache.org/docs/r2.10.1/api/org/apache/hadoop/mapreduce/lib/output/FileOutputFormatCounter.html

# %%
job_id = "job_1596895008206_20293" # replace this value with the one from your job. Using the unaltered value will not work
# !mapred job -counter $job_id org.apache.hadoop.mapreduce.TaskCounter MAP_INPUT_RECORDS
# Out:
# 21/04/25 10:00:53 INFO client.RMProxy: Connecting to ResourceManager at c100.local/10.7.0.100:8032
# 21/04/25 10:00:54 INFO mapred.ClientServiceDelegate: Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 13518773

# %%
# !mapred job -counter $job_id org.apache.hadoop.mapreduce.TaskCounter MAP_OUTPUT_RECORDS
# Out:
# 21/04/25 10:01:00 INFO client.RMProxy: Connecting to ResourceManager at c100.local/10.7.0.100:8032
# 21/04/25 10:01:01 INFO mapred.ClientServiceDelegate: Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 13518772

# %%
# !mapred job -counter $job_id org.apache.hadoop.mapreduce.TaskCounter MAP_OUTPUT_BYTES
# Out:
# 21/04/25 10:01:07 INFO client.RMProxy: Connecting to ResourceManager at c100.local/10.7.0.100:8032
# 21/04/25 10:01:08 INFO mapred.ClientServiceDelegate: Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 289954224

# %%
# !mapred job -counter $job_id org.apache.hadoop.mapreduce.lib.input.FileInputFormatCounter BYTES_READ
# Out:
# 21/04/25 10:01:13 INFO client.RMProxy: Connecting to ResourceManager at c100.local/10.7.0.100:8032
# 21/04/25 10:01:14 INFO mapred.ClientServiceDelegate: Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 2278886238

# %%
# !mapred job -counter $job_id org.apache.hadoop.mapreduce.lib.output.FileOutputFormatCounter BYTES_WRITTEN
# Out:
# 21/04/25 10:01:18 INFO client.RMProxy: Connecting to ResourceManager at c100.local/10.7.0.100:8032
# 21/04/25 10:01:18 INFO mapred.ClientServiceDelegate: Application state is completed. FinalApplicationStatus=SUCCEEDED. Redirecting to job history server
# 258967

# %% [markdown]
# ### Replication Rates and Input and Output Sizes:
#
# * Replication Rate for Task 1. :   **13518772/17**
# * Communication Cost:  **13518773 + 2*13518772 +258967**
# *  Input Size for Task 1. :   **2278886238**
# * Output Size for Task 1. :  **258967**

# %% [markdown]
# Note: if your job had multiple steps, just state the replication rates  for each step.
# Make sure to compute the cummulative costs for the other measures, though, especially for the communication cost. For a multi-step MR job, **also count the communication between steps** towards the total communication cost of the job.
# * Replication Rate for Task 2. :  **YOUR ANSWER HERE**
# * Communication Cost:  **YOUR ANSWER HERE**
# * Input Size for Task 2. :  **YOUR ANSWER HERE**
# * Output Size for Task 2. :  **YOUR ANSWER HERE**

# %% [markdown]
# For more counters, you can check the documentation, under https://hadoop.apache.org/docs/current/api/org/apache/hadoop/mapreduce/TaskCounter and https://hadoop.apache.org/docs/current/api/org/apache/hadoop/mapreduce/lib/output/FileOutputFormatCounter.html

# %% [markdown]
# ---
# ## **Your solution for Exercise 3 will consist of:**
# *  This notebook, filled with your solution, including the information on the replication rate, and the input and output sizes.
# _Submissions which do not run on the cluster will not be counted as valid._
